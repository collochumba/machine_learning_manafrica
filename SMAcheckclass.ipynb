# %%
from smabacktester import SMABacktester

# %%
tester = SMABacktester("AAPL",1,200,"2000-01-01", "2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (np.float64(211.711354), np.float64(-8.049089))

# %%
tester.plot_results()
