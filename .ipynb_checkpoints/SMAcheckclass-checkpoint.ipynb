# %%
from smabacktester import SMABacktester
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from smabacktester import SMABacktester
#
# ModuleNotFoundError: No module named 'smabacktester'
