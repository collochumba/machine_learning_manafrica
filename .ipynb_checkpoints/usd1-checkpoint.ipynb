#
# Price                                 Volume
# Ticker             KO         SPY       AAPL        KO        SPY
# Date
# 2015-01-02  30.078011  171.884913  212818400   9921100  121465900
# 2015-01-05  30.384058  170.044264  257142000  26292600  169632600
# 2015-01-06  30.184772  168.311931  263188400  16897500  209151400
# 2015-01-07  30.462341  167.753921  160423600  13412300  125346700
# 2015-01-08  30.732804  169.911040  237458000  21743600  147217800
# ...               ...         ...        ...       ...        ...
# 2024-12-24  60.841848  590.882430   23234700   5019100   33160100
# 2024-12-26  61.252673  594.292655   27237100   7943800   41219100
# 2024-12-27  61.086388  592.349606   42355300   8542800   64969300
# 2024-12-30  60.978789  582.783445   35557500   8972200   56578800
# 2024-12-31  60.665774  584.785824   39480700   9256700   57052700
#
# [2516 rows x 15 columns]

# %%
stocks.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close',   'KO'),
#             ( 'Close',  'SPY'),
#             (  'High', 'AAPL'),
#             (  'High',   'KO'),
#             (  'High',  'SPY'),
#             (   'Low', 'AAPL'),
#             (   'Low',   'KO'),
#             (   'Low',  'SPY'),
#             (  'Open', 'AAPL'),
#             (  'Open',   'KO'),
#             (  'Open',  'SPY'),
#             ('Volume', 'AAPL'),
#             ('Volume',   'KO'),
#             ('Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
#convert multiindex to one tuple
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([ ('Close', 'AAPL'),    ('Close', 'KO'),   ('Close', 'SPY'),
#          ('High', 'AAPL'),     ('High', 'KO'),    ('High', 'SPY'),
#           ('Low', 'AAPL'),      ('Low', 'KO'),     ('Low', 'SPY'),
#          ('Open', 'AAPL'),     ('Open', 'KO'),    ('Open', 'SPY'),
#        ('Volume', 'AAPL'),   ('Volume', 'KO'),  ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2015-01-02      24.261045    29.992603    171.093689     24.729268
# 2015-01-05      23.577574    29.992603    168.003769     24.110150
# 2015-01-06      23.579790    30.220358    166.421356     23.839420
# 2015-01-07      23.910439    30.597572    168.495163     24.010296
# 2015-01-08      24.829126    30.967676    171.485138     24.886823
# ...                   ...          ...           ...           ...
# 2024-12-24     257.286682    61.467873    596.076904    257.296626
# 2024-12-26     258.103729    61.203766    596.116699    259.179926
# 2024-12-27     254.685867    61.086388    589.841614    257.784882
# 2024-12-30     251.307877    60.675556    583.110535    252.603281
# 2024-12-31     249.534180    60.900532    580.989136    252.384064
#
#             (High, KO)  (High, SPY)  (Low, AAPL)  (Low, KO)  (Low, SPY)  \
# Date
# 2015-01-02   30.177656   172.301341    23.821670  29.750613  170.052618
# 2015-01-05   30.583346   170.210833    23.391173  29.949901  167.695616
# 2015-01-06   30.561991   168.836634    23.218081  30.063778  165.621809
# 2015-01-07   30.682980   168.836637    23.677436  30.305760  167.304185
# 2015-01-08   31.010381   171.701689    24.121244  30.675864  169.894392
# ...                ...          ...          ...        ...         ...
columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
ax = close.plot(figsize=(12,6), fontsize = 12)
ax.set_title("Closing Prices for AAPL KO SPY")
ax.set_xlabel("Date")
ax.set_ylabel("price")
plt.tight_layout()
plt.legend(fontsize = 12)
plt.show() # forces render to show the grid to show

# %%
# let start normalizing the data
close.iloc[0,0] #first index of the dataframe
# Out:
# np.float64(24.261045455932617)

# %%
close.AAPL
# Out:
# Date
# 2015-01-02     24.261045
# 2015-01-05     23.577574
# 2015-01-06     23.579790
# 2015-01-07     23.910439
# 2015-01-08     24.829126
#                  ...
# 2024-12-24    257.286682
# 2024-12-26    258.103729
# 2024-12-27    254.685867
# 2024-12-30    251.307877
# 2024-12-31    249.534180
# Name: AAPL, Length: 2516, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])#divides the the rest with first index to normalize the data
# Out:
# Date
# 2015-01-02     1.000000
# 2015-01-05     0.971828
# 2015-01-06     0.971920
# 2015-01-07     0.985549
# 2015-01-08     1.023415
#                 ...
# 2024-12-24    10.604930
# 2024-12-26    10.638607
# 2024-12-27    10.497728
# 2024-12-30    10.358493
# 2024-12-31    10.285384
# Name: AAPL, Length: 2516, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL     24.261045
# KO       29.992603
# SPY     171.093689
# Name: 2015-01-02 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100) # normalize all the data and multiplies by 100
# Out:
#                    AAPL          KO         SPY
# Date
# 2015-01-02   100.000000  100.000000  100.000000
# 2015-01-05    97.182843  100.000000   98.194019
# 2015-01-06    97.191979  100.759369   97.269138
# 2015-01-07    98.554857  102.017061   98.481226
# 2015-01-08   102.341535  103.251044  100.228792
# ...                 ...         ...         ...
# 2024-12-24  1060.492973  204.943439  348.392105
# 2024-12-26  1063.860705  204.062866  348.415364
# 2024-12-27  1049.772846  203.671509  344.747733
# 2024-12-30  1035.849329  202.301733  340.813585
# 2024-12-31  1028.538445  203.051836  339.573680
#
# [2516 rows x 3 columns]

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
ab = normclose.plot(figsize=(12,6), fontsize = 12)
ab.set_title("Normalized Close data for AAPL SPY KO")
ab.set_xlabel("Date")
ab.set_ylabel("Price")
plt.legend(fontsize = 12)
plt.show()

# %%
#want to focus now on the aple stock.
aapl = close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2015-01-02   24.261045
# 2015-01-05   23.577574
# 2015-01-06   23.579790
# 2015-01-07   23.910439
# 2015-01-08   24.829126
# ...                ...
# 2024-12-24  257.286682
# 2024-12-26  258.103729
# 2024-12-27  254.685867
# 2024-12-30  251.307877
# 2024-12-31  249.534180
#
# [2516 rows x 1 columns]

# %%
aapl.shift( periods = 1) #
# Out:
#                   AAPL
# Date
# 2015-01-02         NaN
# 2015-01-05   24.261045
# 2015-01-06   23.577574
# 2015-01-07   23.579790
# 2015-01-08   23.910439
# ...                ...
# 2024-12-24  254.367020
# 2024-12-26  257.286682
# 2024-12-27  258.103729
# 2024-12-30  254.685867
# 2024-12-31  251.307877
#
# [2516 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods = 1) # this creates another column in dataframe of aapl

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2015-01-02   24.261045         NaN
# 2015-01-05   23.577574   24.261045
# 2015-01-06   23.579790   23.577574
# 2015-01-07   23.910439   23.579790
# 2015-01-08   24.829126   23.910439
# ...                ...         ...
# 2024-12-24  257.286682  254.367020
# 2024-12-26  258.103729  257.286682
# 2024-12-27  254.685867  258.103729
# 2024-12-30  251.307877  254.685867
# 2024-12-31  249.534180  251.307877
#
# [2516 rows x 2 columns]

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1) #(Diff) that shows day-to-day price movement

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2015-01-02   24.261045         NaN       NaN
# 2015-01-05   23.577574   24.261045 -0.683472
# 2015-01-06   23.579790   23.577574  0.002216
# 2015-01-07   23.910439   23.579790  0.330648
# 2015-01-08   24.829126   23.910439  0.918688
# ...                ...         ...       ...
# 2024-12-24  257.286682  254.367020  2.919662
# 2024-12-26  258.103729  257.286682  0.817047
# 2024-12-27  254.685867  258.103729 -3.417862
# 2024-12-30  251.307877  254.685867 -3.377991
# 2024-12-31  249.534180  251.307877 -1.773697
#
# [2516 rows x 3 columns]

# %%
aapl["% change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % change
# Date
# 2015-01-02   24.261045         NaN       NaN       NaN
# 2015-01-05   23.577574   24.261045 -0.683472 -2.817157
# 2015-01-06   23.579790   23.577574  0.002216  0.009400
# 2015-01-07   23.910439   23.579790  0.330648  1.402253
# 2015-01-08   24.829126   23.910439  0.918688  3.842204
# ...                ...         ...       ...       ...
# 2024-12-24  257.286682  254.367020  2.919662  1.147815
# 2024-12-26  258.103729  257.286682  0.817047  0.317563
# 2024-12-27  254.685867  258.103729 -3.417862 -1.324220
# 2024-12-30  251.307877  254.685867 -3.377991 -1.326336
# 2024-12-31  249.534180  251.307877 -1.773697 -0.705786
#
# [2516 rows x 4 columns]

# %%
aapl["% change 2"] = aapl.AAPL.pct_change(periods = 1).mul(100) # make the percentage change into readable percentages
aapl
# Out:
#                   AAPL        lag1      Diff  % change  % change 2
# Date
# 2015-01-02   24.261045         NaN       NaN       NaN         NaN
# 2015-01-05   23.577574   24.261045 -0.683472 -2.817157   -2.817157
# 2015-01-06   23.579790   23.577574  0.002216  0.009400    0.009400
# 2015-01-07   23.910439   23.579790  0.330648  1.402253    1.402253
# 2015-01-08   24.829126   23.910439  0.918688  3.842204    3.842204
# ...                ...         ...       ...       ...         ...
# 2024-12-24  257.286682  254.367020  2.919662  1.147815    1.147815
# 2024-12-26  258.103729  257.286682  0.817047  0.317563    0.317563
# 2024-12-27  254.685867  258.103729 -3.417862 -1.324220   -1.324220
# 2024-12-30  251.307877  254.685867 -3.377991 -1.326336   -1.326336
# 2024-12-31  249.534180  251.307877 -1.773697 -0.705786   -0.705786
#
# [2516 rows x 5 columns]

# %%
del aapl["lag1"]
del aapl["Diff"]
del aapl["% change"] # deleting columns

# %%
aapl
# Out:
#                   AAPL  % change 2
# Date
# 2015-01-02   24.261045         NaN
# 2015-01-05   23.577574   -2.817157
# 2015-01-06   23.579790    0.009400
# 2015-01-07   23.910439    1.402253
# 2015-01-08   24.829126    3.842204
# ...                ...         ...
# 2024-12-24  257.286682    1.147815
# 2024-12-26  258.103729    0.317563
# 2024-12-27  254.685867   -1.324220
# 2024-12-30  251.307877   -1.326336
# 2024-12-31  249.534180   -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.rename( columns = {"% change 2" : "change"}, inplace = True)

# %%
aapl
# Out:
#                   AAPL    change
# Date
# 2015-01-02   24.261045       NaN
# 2015-01-05   23.577574 -2.817157
# 2015-01-06   23.579790  0.009400
# 2015-01-07   23.910439  1.402253
# 2015-01-08   24.829126  3.842204
# ...                ...       ...
# 2024-12-24  257.286682  1.147815
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307877 -1.326336
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("M").last() # gives monthly
aapl
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14608\2082094181.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   aapl.AAPL.resample("M").last() # gives monthly
#                   AAPL    change
# Date
# 2015-01-02   24.261045       NaN
# 2015-01-05   23.577574 -2.817157
# 2015-01-06   23.579790  0.009400
# 2015-01-07   23.910439  1.402253
# 2015-01-08   24.829126  3.842204
# ...                ...       ...
# 2024-12-24  257.286682  1.147815
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307877 -1.326336
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("BM").last()# gives last business day
aapl
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14608\1414886035.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample("BM").last()# gives last business day
#                   AAPL    change
# Date
# 2015-01-02   24.261045       NaN
# 2015-01-05   23.577574 -2.817157
# 2015-01-06   23.579790  0.009400
# 2015-01-07   23.910439  1.402253
# 2015-01-08   24.829126  3.842204
# ...                ...       ...
# 2024-12-24  257.286682  1.147815
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307877 -1.326336
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("BME").last().pct_change(periods = 1).mul(100) # gives percentage change last business day
aapl
# Out:
#                   AAPL    change
# Date
# 2015-01-02   24.261045       NaN
# 2015-01-05   23.577574 -2.817157
# 2015-01-06   23.579790  0.009400
# 2015-01-07   23.910439  1.402253
# 2015-01-08   24.829126  3.842204
# ...                ...       ...
# 2024-12-24  257.286682  1.147815
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307877 -1.326336
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL      change
# Date
# 2015-01-06  0.000094   -1.003337
# 2015-01-07  0.014023  148.172724
# 2015-01-08  0.038422    1.740021
# 2015-01-09  0.001072   -0.972087
# 2015-01-12 -0.024641  -23.975789
# ...              ...         ...
# 2024-12-24  0.011478    2.744986
# 2024-12-26  0.003176   -0.723333
# 2024-12-27 -0.013242   -5.169946
# 2024-12-30 -0.013263    0.001598
# 2024-12-31 -0.007058   -0.467868
#
# [2514 rows x 2 columns]

# %%
ret.replace([float("inf"), float("-inf")], float("nan"), inplace=True)
ret = ret.dropna()
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()

# %%
ret['AAPL'] = ret['AAPL'].apply(lambda x: np.log(x+1) if x > 0 else x)
ret['change'] = ret['change'].apply(lambda x: np.log(abs(x)+1) if x != 0 else x)
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14608\1755525925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ret['AAPL'] = ret['AAPL'].apply(lambda x: np.log(x+1) if x > 0 else x)
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14608\1755525925.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ret['change'] = ret['change'].apply(lambda x: np.log(abs(x)+1) if x != 0 else x)

# %%
ax = ret['AAPL'].plot(kind="hist", figsize=(12,8), bins=100, color="blue", alpha=0.5)
ret['change'].plot(kind="hist", bins=100, color="orange", alpha=0.5, ax=ax)
ax.set_ylabel('Frequency')
ax.set_title('Stock Price and Change Histogram')
plt.legend(["AAPL", "change"])
plt.show()

# %%
daily_mean_return = ret.mean()
daily_mean_return
# Out:
# AAPL      0.001024
# change    1.081110
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL      0.000314
# change    0.660218
# dtype: float64

# %%
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL      0.017727
# change    0.812538
# dtype: float64

# %%
ret.std()
# Out:
# AAPL      0.017727
# change    0.812538
# dtype: float64

# %%
annual_mean_ret = daily_mean_return*252
annual_mean_ret
# Out:
# AAPL        0.257981
# change    272.439832
# dtype: float64

# %%
annual_var = var_daily * 252
annual_var
# Out:
# AAPL        0.079192
# change    166.375007
# dtype: float64

# %%
annual_std = np.sqrt(annual_var)
annual_std
# Out:
# AAPL       0.281411
# change    12.898644
# dtype: float64

# %%
ticker = ["SPY","AAPL","kO","IBM","DIS","MSFT"]
stocks=yf.download(ticker, start = "2015-01-01" , end = "2025-01-01")
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14608\4157262885.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks=yf.download(ticker, start = "2015-01-01" , end = "2025-01-01")
# [*********************100%***********************]  6 of 6 completed

# %%
close = stocks.loc[ :,"Close"].copy() #choose the close
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2015-01-05 -0.028172 -0.014613 -0.015735  0.000000 -0.009196 -0.018060
# 2015-01-06  0.000094 -0.005304 -0.021566  0.007594 -0.014678 -0.009419
# 2015-01-07  0.014023  0.010230 -0.006536  0.012482  0.012705  0.012461
# 2015-01-08  0.038422  0.010341  0.021735  0.012096  0.029418  0.017745
# 2015-01-09  0.001072  0.004905  0.004356 -0.011032 -0.008405 -0.008014

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    2515.0  0.001088  0.017929 -0.128647 -0.007326  0.001001  0.010142
# DIS     2515.0  0.000255  0.017537 -0.131632 -0.007131  0.000098  0.008085
# IBM     2515.0  0.000424  0.015004 -0.128507 -0.006349  0.000768  0.007403
# KO      2515.0  0.000345  0.011204 -0.096725 -0.004593  0.000551  0.005747
# MSFT    2515.0  0.001081  0.017096 -0.147390 -0.006736  0.000958  0.009769
# SPY     2515.0  0.000548  0.011099 -0.109424 -0.003705  0.000596  0.005928
#
#              max
# Ticker
# AAPL    0.119808
# DIS     0.144123
# IBM     0.113011
# KO      0.064796
# MSFT    0.142169
# SPY     0.090603

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001088  0.017929
# DIS     0.000255  0.017537
# IBM     0.000424  0.015004
# KO      0.000345  0.011204
# MSFT    0.001081  0.017096
# SPY     0.000548  0.011099

# %%
summary ["mean"]= summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.274140  0.284617
# DIS     0.064184  0.278397
# IBM     0.106780  0.238178
# KO      0.086883  0.177859
# MSFT    0.272487  0.271390
# SPY     0.138110  0.176192

# %%
summary.plot.scatter(x="std", y="mean",figsize=(12,8), s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i,"std"]+ 0.002, summary.loc[i, "mean"]+0.02), size=15)
plt.show()

# %% [markdown]
# Correlation and covariance

# %%
ret
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2015-01-05 -0.028172 -0.014613 -0.015735  0.000000 -0.009196 -0.018060
# 2015-01-06  0.000094 -0.005304 -0.021566  0.007594 -0.014678 -0.009419
# 2015-01-07  0.014023  0.010230 -0.006536  0.012482  0.012705  0.012461
# 2015-01-08  0.038422  0.010341  0.021735  0.012096  0.029418  0.017745
# 2015-01-09  0.001072  0.004905  0.004356 -0.011032 -0.008405 -0.008014
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-24  0.011478  0.010413  0.011175  0.007374  0.009374  0.011115
# 2024-12-26  0.003176 -0.000089  0.002139 -0.004297 -0.002777  0.000067
# 2024-12-27 -0.013242 -0.008885 -0.009382 -0.001918 -0.017302 -0.010527
# 2024-12-30 -0.013263 -0.006723 -0.011357 -0.006725 -0.013240 -0.011412
# 2024-12-31 -0.007058  0.004964 -0.001907  0.003708 -0.007838 -0.003638
#
# [2515 rows x 6 columns]

# %%
ret.cov() # coverance of the matrix
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    0.000321  0.000130  0.000107  0.000074  0.000209  0.000149
# DIS     0.000130  0.000308  0.000106  0.000078  0.000132  0.000122
# IBM     0.000107  0.000106  0.000225  0.000079  0.000113  0.000105
# KO      0.000074  0.000078  0.000079  0.000126  0.000077  0.000073
# MSFT    0.000209  0.000132  0.000113  0.000077  0.000292  0.000151
# SPY     0.000149  0.000122  0.000105  0.000073  0.000151  0.000123

# %%
ret.corr()#correlation of the matrix
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    1.000000  0.413371  0.397703  0.367808  0.682852  0.747368
# DIS     0.413371  1.000000  0.401442  0.395461  0.441455  0.628928
# IBM     0.397703  0.401442  1.000000  0.469248  0.440134  0.628158
# KO      0.367808  0.395461  0.469248  1.000000  0.402614  0.589649
# MSFT    0.682852  0.441455  0.440134  0.402614  1.000000  0.795566
# SPY     0.747368  0.628928  0.628158  0.589649  0.795566  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))#size of the figure
sns.set(font_scale =1.4)#this is the scale of the font how big or small it is
sns.heatmap(ret.corr(),cmap="Greens",annot=True,annot_kws={"size":15},vmax=0.6)# thsi is the heatmap with setting like color for cmapaand annotation settings
plt.show()# so that the map is show

# %% [markdown]
# #Simple returns and logs

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95], columns=['Prices'])

# %%
df
# Out:
#       Prices
# 2016     100
# 2017      50
# 2018      95

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       Prices
# 2017    -0.5
# 2018     0.9

# %%
simplereturns.mean()
# Out:
# Prices    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
#the simple returns is misleading and therefore we should use the logs since it drops the first data for 2016
#the above cell was suppose to end in 95 as in the df dataframe

# %%
logreturns =np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#         Prices
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Prices   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2) # it should give 95
# Out:
# Prices    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14608\2286755956.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   SPY = yf.download("SPY")
# [*********************100%***********************]  1 of 1 completed

# %%
spy = SPY["Close"].to_Frame()# make the close into a dataframe for SPY
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14608\2461515883.py in ?()
# ----> 1 spy = SPY["Close"].to_frame()# make the close into a dataframe for SPY
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'
