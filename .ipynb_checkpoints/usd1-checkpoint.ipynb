# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2015-01-01" , end = "2025-01-01")# downloading the data for apple AAPL is the trade mark for apple.
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2015-01-02   24.237553   24.705322   23.798602   24.694237  212818400
# 2015-01-05   23.554741   24.086801   23.368521   24.006992  257142000
# 2015-01-06   23.556953   23.816332   23.195595   23.619027  263188400
# 2015-01-07   23.887274   23.987034   23.654497   23.765343  160423600
# 2015-01-08   24.805080   24.862721   24.097883   24.215381  237458000
# ...                ...         ...         ...         ...        ...
# 2024-12-24  257.037476  257.047410  254.140559  254.339671   23234700
# 2024-12-26  257.853760  258.928914  256.470034  257.027510   27237100
# 2024-12-27  254.439240  257.535253  251.920632  256.669145   42355300
# 2024-12-30  251.064499  252.358649  249.621030  251.094363   35557500
# 2024-12-31  249.292496  252.139619  248.306948  251.303405   39480700
#
# [2516 rows x 5 columns]

# %%
ticker = ["SPY","AAPL","kO"]

# %%
stocks = yf.download(ticker, start = "2015-01-01" , end = "2025-01-01") # this is downloading the multiple stocks
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
stocks
# Out:
# Price            Close                               High             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2015-01-02   24.237553  29.783403  170.589615   24.705322  29.967166
# 2015-01-05   23.554741  29.783403  167.508835   24.086801  30.370026
# 2015-01-06   23.556953  30.009563  165.931076   23.816332  30.348814
# 2015-01-07   23.887274  30.384159  167.998764   23.987034  30.468971
# 2015-01-08   24.805080  30.751684  170.979889   24.862721  30.794092
# ...                ...        ...         ...         ...        ...
# 2024-12-24  257.037476  61.039146  594.320801  257.047410  61.039146
# 2024-12-26  257.853760  60.776886  594.360352  258.928914  60.942016
# 2024-12-27  254.439240  60.660320  588.103882  257.535253  61.145991
# 2024-12-30  251.064499  60.252354  581.392517  252.358649  60.553471
# 2024-12-31  249.292496  60.475761  579.277466  252.139619  60.640892
#
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2015-01-02 to 2024-12-31
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   2516 non-null   float64
#  1   (Close, KO)     2516 non-null   float64
#  2   (Close, SPY)    2516 non-null   float64
#  3   (High, AAPL)    2516 non-null   float64
#  4   (High, KO)      2516 non-null   float64
#  5   (High, SPY)     2516 non-null   float64
#  6   (Low, AAPL)     2516 non-null   float64
#  7   (Low, KO)       2516 non-null   float64
#  8   (Low, SPY)      2516 non-null   float64
#  9   (Open, AAPL)    2516 non-null   float64
#  10  (Open, KO)      2516 non-null   float64
#  11  (Open, SPY)     2516 non-null   float64
#  12  (Volume, AAPL)  2516 non-null   int64
#  13  (Volume, KO)    2516 non-null   int64
#  14  (Volume, SPY)   2516 non-null   int64
# dtypes: float64(12), int64(3)
# memory usage: 314.5 KB

# %%
stocks.to_csv("stocksticker")# using to_csv function to downloaded the stock data

# %%
stocks = pd.read_csv("stocksticker") # read the downloaded csv  file

# %%
stocks
# Out:
#            Price               Close             Close.1             Close.2  \
# 0         Ticker                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2015-01-02  24.237552642822266  29.783403396606445  170.58961486816406
# 3     2015-01-05   23.55474090576172  29.783403396606445   167.5088348388672
# 4     2015-01-06   23.55695343017578  30.009563446044922   165.9310760498047
# ...          ...                 ...                 ...                 ...
# 2513  2024-12-24   257.0374755859375  61.039146423339844     594.32080078125
# 2514  2024-12-26    257.853759765625  60.776885986328125      594.3603515625
# 2515  2024-12-27  254.43923950195312   60.66032028198242   588.1038818359375
# 2516  2024-12-30   251.0644989013672   60.25235366821289   581.3925170898438
# 2517  2024-12-31  249.29249572753906   60.47576141357422   579.2774658203125
#
# ...

# %%
stocks = pd.read_csv("stocksticker" , header = [0,1], index_col = [0], parse_dates = [0])
stocks
# Out:
# Price            Close                               High             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2015-01-02   24.237553  29.783403  170.589615   24.705322  29.967166
# 2015-01-05   23.554741  29.783403  167.508835   24.086801  30.370026
# 2015-01-06   23.556953  30.009563  165.931076   23.816332  30.348814
# 2015-01-07   23.887274  30.384159  167.998764   23.987034  30.468971
# 2015-01-08   24.805080  30.751684  170.979889   24.862721  30.794092
# ...                ...        ...         ...         ...        ...
# 2024-12-24  257.037476  61.039146  594.320801  257.047410  61.039146
# 2024-12-26  257.853760  60.776886  594.360352  258.928914  60.942016
# 2024-12-27  254.439240  60.660320  588.103882  257.535253  61.145991
# 2024-12-30  251.064499  60.252354  581.392517  252.358649  60.553471
# 2024-12-31  249.292496  60.475761  579.277466  252.139619  60.640892
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close',   'KO'),
#             ( 'Close',  'SPY'),
#             (  'High', 'AAPL'),
#             (  'High',   'KO'),
#             (  'High',  'SPY'),
#             (   'Low', 'AAPL'),
#             (   'Low',   'KO'),
#             (   'Low',  'SPY'),
#             (  'Open', 'AAPL'),
#             (  'Open',   'KO'),
#             (  'Open',  'SPY'),
#             ('Volume', 'AAPL'),
#             ('Volume',   'KO'),
#             ('Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
#convert multiindex to one tuple
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([ ('Close', 'AAPL'),    ('Close', 'KO'),   ('Close', 'SPY'),
#          ('High', 'AAPL'),     ('High', 'KO'),    ('High', 'SPY'),
#           ('Low', 'AAPL'),      ('Low', 'KO'),     ('Low', 'SPY'),
#          ('Open', 'AAPL'),     ('Open', 'KO'),    ('Open', 'SPY'),
#        ('Volume', 'AAPL'),   ('Volume', 'KO'),  ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2015-01-02      24.237553    29.783403    170.589615     24.705322
# 2015-01-05      23.554741    29.783403    167.508835     24.086801
# 2015-01-06      23.556953    30.009563    165.931076     23.816332
# 2015-01-07      23.887274    30.384159    167.998764     23.987034
# 2015-01-08      24.805080    30.751684    170.979889     24.862721
# ...                   ...          ...           ...           ...
# 2024-12-24     257.037476    61.039146    594.320801    257.047410
# 2024-12-26     257.853760    60.776886    594.360352    258.928914
# 2024-12-27     254.439240    60.660320    588.103882    257.535253
# 2024-12-30     251.064499    60.252354    581.392517    252.358649
# 2024-12-31     249.292496    60.475761    579.277466    252.139619
#
#             (High, KO)  (High, SPY)  (Low, AAPL)  (Low, KO)  (Low, SPY)  \
# Date
# 2015-01-02   29.967166   171.793709    23.798602  29.543101  169.551612
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)# convert tuples to multi index
stocks
# Out:
#                  Close                               High             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2015-01-02   24.237553  29.783403  170.589615   24.705322  29.967166
# 2015-01-05   23.554741  29.783403  167.508835   24.086801  30.370026
# 2015-01-06   23.556953  30.009563  165.931076   23.816332  30.348814
# 2015-01-07   23.887274  30.384159  167.998764   23.987034  30.468971
# 2015-01-08   24.805080  30.751684  170.979889   24.862721  30.794092
# ...                ...        ...         ...         ...        ...
# 2024-12-24  257.037476  61.039146  594.320801  257.047410  61.039146
# 2024-12-26  257.853760  60.776886  594.360352  258.928914  60.942016
# 2024-12-27  254.439240  60.660320  588.103882  257.535253  61.145991
# 2024-12-30  251.064499  60.252354  581.392517  252.358649  60.553471
# 2024-12-31  249.292496  60.475761  579.277466  252.139619  60.640892
#
# ...

# %%
stocks.describe()
# Out:
#              Close                                   High               \
#               AAPL           KO          SPY         AAPL           KO
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# mean     93.858935    43.464288   310.313321    94.770442    43.757039
# std      65.441290    10.724276   114.487024    66.034714    10.797283
# min      20.604076    27.296452   154.980865    20.907414    27.677884
# 25%      35.222940    33.927669   212.172810    35.620874    34.182430
# 50%      64.388012    41.904976   273.214310    64.942753    42.279436
# 75%     150.234020    54.120624   399.331306   151.982043    54.604517
# max     257.853760    69.904625   598.740112   258.928914    70.402491
#
#                             Low                                   Open  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# ...

# %%
close = stocks.loc[:,'Close'].copy() # copy the details to close

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2015-01-02   24.237553  29.783403  170.589615
# 2015-01-05   23.554741  29.783403  167.508835
# 2015-01-06   23.556953  30.009563  165.931076
# 2015-01-07   23.887274  30.384159  167.998764
# 2015-01-08   24.805080  30.751684  170.979889
# ...                ...        ...         ...
# 2024-12-24  257.037476  61.039146  594.320801
# 2024-12-26  257.853760  60.776886  594.360352
# 2024-12-27  254.439240  60.660320  588.103882
# 2024-12-30  251.064499  60.252354  581.392517
# 2024-12-31  249.292496  60.475761  579.277466
#
# [2516 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
ax = close.plot(figsize=(12,6), fontsize = 12)
ax.set_title("Closing Prices for AAPL KO SPY")
ax.set_xlabel("Date")
ax.set_ylabel("price")
plt.tight_layout()
plt.legend(fontsize = 12)
plt.show() # forces render to show the grid to show

# %%
# let start normalizing the data
close.iloc[0,0] #first index of the dataframe
# Out:
# np.float64(24.237552642822266)

# %%
close.AAPL
# Out:
# Date
# 2015-01-02     24.237553
# 2015-01-05     23.554741
# 2015-01-06     23.556953
# 2015-01-07     23.887274
# 2015-01-08     24.805080
#                  ...
# 2024-12-24    257.037476
# 2024-12-26    257.853760
# 2024-12-27    254.439240
# 2024-12-30    251.064499
# 2024-12-31    249.292496
# Name: AAPL, Length: 2516, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])#divides the the rest with first index to normalize the data
# Out:
# Date
# 2015-01-02     1.000000
# 2015-01-05     0.971828
# 2015-01-06     0.971920
# 2015-01-07     0.985548
# 2015-01-08     1.023415
#                 ...
# 2024-12-24    10.604927
# 2024-12-26    10.638605
# 2024-12-27    10.497728
# 2024-12-30    10.358492
# 2024-12-31    10.285382
# Name: AAPL, Length: 2516, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL     24.237553
# KO       29.783403
# SPY     170.589615
# Name: 2015-01-02 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100) # normalize all the data and multiplies by 100
# Out:
#                    AAPL          KO         SPY
# Date
# 2015-01-02   100.000000  100.000000  100.000000
# 2015-01-05    97.182835  100.000000   98.194040
# 2015-01-06    97.191964  100.759349   97.269155
# 2015-01-07    98.554809  102.017082   98.481238
# 2015-01-08   102.341523  103.251075  100.228779
# ...                 ...         ...         ...
# 2024-12-24  1060.492696  204.943490  348.392135
# 2024-12-26  1063.860546  204.062931  348.415319
# 2024-12-27  1049.772818  203.671553  344.747763
# 2024-12-30  1035.849215  202.301775  340.813547
# 2024-12-31  1028.538233  203.051883  339.573699
#
# [2516 rows x 3 columns]

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
ab = normclose.plot(figsize=(12,6), fontsize = 12)
ab.set_title("Normalized Close data for AAPL SPY KO")
ab.set_xlabel("Date")
ab.set_ylabel("Price")
plt.legend(fontsize = 12)
plt.show()

# %%
#want to focus now on the aple stock.
aapl = close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2015-01-02   24.237553
# 2015-01-05   23.554741
# 2015-01-06   23.556953
# 2015-01-07   23.887274
# 2015-01-08   24.805080
# ...                ...
# 2024-12-24  257.037476
# 2024-12-26  257.853760
# 2024-12-27  254.439240
# 2024-12-30  251.064499
# 2024-12-31  249.292496
#
# [2516 rows x 1 columns]

# %%
aapl.shift( periods = 1) #
# Out:
#                   AAPL
# Date
# 2015-01-02         NaN
# 2015-01-05   24.237553
# 2015-01-06   23.554741
# 2015-01-07   23.556953
# 2015-01-08   23.887274
# ...                ...
# 2024-12-24  254.120667
# 2024-12-26  257.037476
# 2024-12-27  257.853760
# 2024-12-30  254.439240
# 2024-12-31  251.064499
#
# [2516 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods = 1) # this creates another column in dataframe of aapl

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2015-01-02   24.237553         NaN
# 2015-01-05   23.554741   24.237553
# 2015-01-06   23.556953   23.554741
# 2015-01-07   23.887274   23.556953
# 2015-01-08   24.805080   23.887274
# ...                ...         ...
# 2024-12-24  257.037476  254.120667
# 2024-12-26  257.853760  257.037476
# 2024-12-27  254.439240  257.853760
# 2024-12-30  251.064499  254.439240
# 2024-12-31  249.292496  251.064499
#
# [2516 rows x 2 columns]

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1) #(Diff) that shows day-to-day price movement

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2015-01-02   24.237553         NaN       NaN
# 2015-01-05   23.554741   24.237553 -0.682812
# 2015-01-06   23.556953   23.554741  0.002213
# 2015-01-07   23.887274   23.556953  0.330320
# 2015-01-08   24.805080   23.887274  0.917807
# ...                ...         ...       ...
# 2024-12-24  257.037476  254.120667  2.916809
# 2024-12-26  257.853760  257.037476  0.816284
# 2024-12-27  254.439240  257.853760 -3.414520
# 2024-12-30  251.064499  254.439240 -3.374741
# 2024-12-31  249.292496  251.064499 -1.772003
#
# [2516 rows x 3 columns]

# %%
aapl["% change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % change
# Date
# 2015-01-02   24.237553         NaN       NaN       NaN
# 2015-01-05   23.554741   24.237553 -0.682812 -2.817165
# 2015-01-06   23.556953   23.554741  0.002213  0.009393
# 2015-01-07   23.887274   23.556953  0.330320  1.402220
# 2015-01-08   24.805080   23.887274  0.917807  3.842241
# ...                ...         ...       ...       ...
# 2024-12-24  257.037476  254.120667  2.916809  1.147805
# 2024-12-26  257.853760  257.037476  0.816284  0.317574
# 2024-12-27  254.439240  257.853760 -3.414520 -1.324208
# 2024-12-30  251.064499  254.439240 -3.374741 -1.326344
# 2024-12-31  249.292496  251.064499 -1.772003 -0.705796
#
# [2516 rows x 4 columns]

# %%
aapl["% change 2"] = aapl.AAPL.pct_change(periods = 1).mul(100) # make the percentage change into readable percentages
aapl
# Out:
#                   AAPL        lag1      Diff  % change  % change 2
# Date
# 2015-01-02   24.237553         NaN       NaN       NaN         NaN
# 2015-01-05   23.554741   24.237553 -0.682812 -2.817165   -2.817165
# 2015-01-06   23.556953   23.554741  0.002213  0.009393    0.009393
# 2015-01-07   23.887274   23.556953  0.330320  1.402220    1.402220
# 2015-01-08   24.805080   23.887274  0.917807  3.842241    3.842241
# ...                ...         ...       ...       ...         ...
# 2024-12-24  257.037476  254.120667  2.916809  1.147805    1.147805
# 2024-12-26  257.853760  257.037476  0.816284  0.317574    0.317574
# 2024-12-27  254.439240  257.853760 -3.414520 -1.324208   -1.324208
# 2024-12-30  251.064499  254.439240 -3.374741 -1.326344   -1.326344
# 2024-12-31  249.292496  251.064499 -1.772003 -0.705796   -0.705796
#
# [2516 rows x 5 columns]

# %%
del aapl["lag1"]
del aapl["Diff"]
del aapl["% change"] # deleting columns

# %%
aapl
# Out:
#                   AAPL  % change 2
# Date
# 2015-01-02   24.237553         NaN
# 2015-01-05   23.554741   -2.817165
# 2015-01-06   23.556953    0.009393
# 2015-01-07   23.887274    1.402220
# 2015-01-08   24.805080    3.842241
# ...                ...         ...
# 2024-12-24  257.037476    1.147805
# 2024-12-26  257.853760    0.317574
# 2024-12-27  254.439240   -1.324208
# 2024-12-30  251.064499   -1.326344
# 2024-12-31  249.292496   -0.705796
#
# [2516 rows x 2 columns]

# %%
aapl.rename( columns = {"% change 2" : "change"}, inplace = True)

# %%
aapl
# Out:
#                   AAPL    change
# Date
# 2015-01-02   24.237553       NaN
# 2015-01-05   23.554741 -2.817165
# 2015-01-06   23.556953  0.009393
# 2015-01-07   23.887274  1.402220
# 2015-01-08   24.805080  3.842241
# ...                ...       ...
# 2024-12-24  257.037476  1.147805
# 2024-12-26  257.853760  0.317574
# 2024-12-27  254.439240 -1.324208
# 2024-12-30  251.064499 -1.326344
# 2024-12-31  249.292496 -0.705796
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("M").last() # gives monthly
aapl
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_24340\2082094181.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   aapl.AAPL.resample("M").last() # gives monthly
#                   AAPL    change
# Date
# 2015-01-02   24.237553       NaN
# 2015-01-05   23.554741 -2.817165
# 2015-01-06   23.556953  0.009393
# 2015-01-07   23.887274  1.402220
# 2015-01-08   24.805080  3.842241
# ...                ...       ...
# 2024-12-24  257.037476  1.147805
# 2024-12-26  257.853760  0.317574
# 2024-12-27  254.439240 -1.324208
# 2024-12-30  251.064499 -1.326344
# 2024-12-31  249.292496 -0.705796
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("BM").last()# gives last business day
aapl
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_24340\1414886035.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample("BM").last()# gives last business day
#                   AAPL    change
# Date
# 2015-01-02   24.237553       NaN
# 2015-01-05   23.554741 -2.817165
# 2015-01-06   23.556953  0.009393
# 2015-01-07   23.887274  1.402220
# 2015-01-08   24.805080  3.842241
# ...                ...       ...
# 2024-12-24  257.037476  1.147805
# 2024-12-26  257.853760  0.317574
# 2024-12-27  254.439240 -1.324208
# 2024-12-30  251.064499 -1.326344
# 2024-12-31  249.292496 -0.705796
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("BME").last().pct_change(periods = 1).mul(100) # gives percentage change last business day
aapl
# Out:
#                   AAPL    change
# Date
# 2015-01-02   24.237553       NaN
# 2015-01-05   23.554741 -2.817165
# 2015-01-06   23.556953  0.009393
# 2015-01-07   23.887274  1.402220
# 2015-01-08   24.805080  3.842241
# ...                ...       ...
# 2024-12-24  257.037476  1.147805
# 2024-12-26  257.853760  0.317574
# 2024-12-27  254.439240 -1.324208
# 2024-12-30  251.064499 -1.326344
# 2024-12-31  249.292496 -0.705796
#
# [2516 rows x 2 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL      change
# Date
# 2015-01-06  0.000094   -1.003334
# 2015-01-07  0.014022  148.281667
# 2015-01-08  0.038422    1.740112
# 2015-01-09  0.001073   -0.972082
# 2015-01-12 -0.024641  -23.971632
# ...              ...         ...
# 2024-12-24  0.011478    2.745002
# 2024-12-26  0.003176   -0.723321
# 2024-12-27 -0.013242   -5.169762
# 2024-12-30 -0.013263    0.001613
# 2024-12-31 -0.007058   -0.467864
#
# [2514 rows x 2 columns]

# %%
ret.replace([float("inf"), float("-inf")], float("nan"), inplace=True)
ret = ret.dropna()
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()

# %%
ret['AAPL'] = ret['AAPL'].apply(lambda x: np.log(x+1) if x > 0 else x)
ret['change'] = ret['change'].apply(lambda x: np.log(abs(x)+1) if x != 0 else x)
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_24340\1755525925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ret['AAPL'] = ret['AAPL'].apply(lambda x: np.log(x+1) if x > 0 else x)
# C:\Users\chumb\AppData\Local\Temp\ipykernel_24340\1755525925.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ret['change'] = ret['change'].apply(lambda x: np.log(abs(x)+1) if x != 0 else x)

# %%
ax = ret['AAPL'].plot(kind="hist", figsize=(12,8), bins=100, color="blue", alpha=0.5)
ret['change'].plot(kind="hist", bins=100, color="orange", alpha=0.5, ax=ax)
ax.set_ylabel('Frequency')
ax.set_title('Stock Price and Change Histogram')
plt.legend(["AAPL", "change"])
plt.show()

# %%
daily_mean_return = ret.mean()
daily_mean_return
# Out:
# AAPL      0.001024
# change    1.081107
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL      0.000314
# change    0.660193
# dtype: float64

# %%
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL      0.017727
# change    0.812523
# dtype: float64

# %%
ret.std()
# Out:
# AAPL      0.017727
# change    0.812523
# dtype: float64

# %%
annual_mean_ret = daily_mean_return*252
annual_mean_ret
# Out:
# AAPL        0.257981
# change    272.438996
# dtype: float64

# %%
annual_var = var_daily * 252
annual_var
# Out:
# AAPL        0.079192
# change    166.368679
# dtype: float64

# %%
annual_std = np.sqrt(annual_var)
annual_std
# Out:
# AAPL       0.281411
# change    12.898398
# dtype: float64

# %%
ticker = ["SPY","AAPL","kO","IBM","DIS","MSFT"]
stocks=yf.download(ticker, start = "2015-01-01" , end = "2025-01-01")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
close = stocks.loc[ :,"Close"].copy() #choose the close
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2015-01-05 -0.028172 -0.014613 -0.015735  0.000000 -0.009196 -0.018060
# 2015-01-06  0.000094 -0.005304 -0.021566  0.007593 -0.014678 -0.009419
# 2015-01-07  0.014022  0.010230 -0.006535  0.012483  0.012705  0.012461
# 2015-01-08  0.038422  0.010342  0.021735  0.012096  0.029418  0.017745
# 2015-01-09  0.001073  0.004904  0.004356 -0.011032 -0.008405 -0.008013

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    2515.0  0.001088  0.017929 -0.128647 -0.007326  0.001001  0.010142
# DIS     2515.0  0.000255  0.017537 -0.131632 -0.007131  0.000098  0.008085
# IBM     2515.0  0.000424  0.015004 -0.128507 -0.006349  0.000767  0.007403
# KO      2515.0  0.000345  0.011204 -0.096725 -0.004592  0.000551  0.005747
# MSFT    2515.0  0.001081  0.017096 -0.147390 -0.006736  0.000959  0.009768
# SPY     2515.0  0.000548  0.011099 -0.109424 -0.003705  0.000596  0.005928
#
#              max
# Ticker
# AAPL    0.119808
# DIS     0.144123
# IBM     0.113011
# KO      0.064796
# MSFT    0.142169
# SPY     0.090603

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001088  0.017929
# DIS     0.000255  0.017537
# IBM     0.000424  0.015004
# KO      0.000345  0.011204
# MSFT    0.001081  0.017096
# SPY     0.000548  0.011099

# %%
summary ["mean"]= summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.274140  0.284618
# DIS     0.064184  0.278397
# IBM     0.106780  0.238178
# KO      0.086883  0.177859
# MSFT    0.272487  0.271390
# SPY     0.138110  0.176192

# %%
summary.plot.scatter(x="std", y="mean",figsize=(12,8), s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i,"std"]+ 0.002, summary.loc[i, "mean"]+0.02), size=15)
plt.show()

# %% [markdown]
# Correlation and covariance

# %%
ret
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2015-01-05 -0.028172 -0.014613 -0.015735  0.000000 -0.009196 -0.018060
# 2015-01-06  0.000094 -0.005304 -0.021566  0.007593 -0.014678 -0.009419
# 2015-01-07  0.014022  0.010230 -0.006535  0.012483  0.012705  0.012461
# 2015-01-08  0.038422  0.010342  0.021735  0.012096  0.029418  0.017745
# 2015-01-09  0.001073  0.004904  0.004356 -0.011032 -0.008405 -0.008013
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-24  0.011478  0.010413  0.011175  0.007374  0.009374  0.011115
# 2024-12-26  0.003176 -0.000089  0.002139 -0.004297 -0.002777  0.000067
# 2024-12-27 -0.013242 -0.008885 -0.009382 -0.001918 -0.017301 -0.010526
# 2024-12-30 -0.013263 -0.006723 -0.011357 -0.006725 -0.013240 -0.011412
# 2024-12-31 -0.007058  0.004964 -0.001907  0.003708 -0.007838 -0.003638
#
# [2515 rows x 6 columns]

# %%
ret.cov() # coverance of the matrix
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    0.000321  0.000130  0.000107  0.000074  0.000209  0.000149
# DIS     0.000130  0.000308  0.000106  0.000078  0.000132  0.000122
# IBM     0.000107  0.000106  0.000225  0.000079  0.000113  0.000105
# KO      0.000074  0.000078  0.000079  0.000126  0.000077  0.000073
# MSFT    0.000209  0.000132  0.000113  0.000077  0.000292  0.000151
# SPY     0.000149  0.000122  0.000105  0.000073  0.000151  0.000123

# %%
ret.corr()#correlation of the matrix
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    1.000000  0.413371  0.397703  0.367808  0.682852  0.747367
# DIS     0.413371  1.000000  0.401442  0.395460  0.441456  0.628928
# IBM     0.397703  0.401442  1.000000  0.469248  0.440134  0.628158
# KO      0.367808  0.395460  0.469248  1.000000  0.402614  0.589649
# MSFT    0.682852  0.441456  0.440134  0.402614  1.000000  0.795566
# SPY     0.747367  0.628928  0.628158  0.589649  0.795566  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))#size of the figure
sns.set(font_scale =1.4)#this is the scale of the font how big or small it is
sns.heatmap(ret.corr(),cmap="Greens",annot=True,annot_kws={"size":15},vmax=0.6)# thsi is the heatmap with setting like color for cmapaand annotation settings
plt.show()# so that the map is show

# %% [markdown]
# #Simple returns and logs

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95], columns=['Prices'])

# %%
df
# Out:
#       Prices
# 2016     100
# 2017      50
# 2018      95

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       Prices
# 2017    -0.5
# 2018     0.9

# %%
simplereturns.mean()
# Out:
# Prices    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
#the simple returns is misleading and therefore we should use the logs since it drops the first data for 2016
#the above cell was suppose to end in 95 as in the df dataframe

# %%
logreturns =np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#         Prices
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Prices   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2) # it should give 95
# Out:
# Prices    95.0
# dtype: float64

# %%
SPY = yf.download("SPY", start="1993-01-01", end="2025-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(SPY.head())
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker            SPY        SPY        SPY        SPY      SPY
# Date
# 1993-01-29  24.241417  24.258658  24.137968  24.258658  1003200
# 1993-02-01  24.413824  24.413824  24.258651  24.258651   480500
# 1993-02-02  24.465553  24.482795  24.344863  24.396588   201300
# 1993-02-03  24.724165  24.741406  24.482785  24.500027   529400
# 1993-02-04  24.827610  24.879334  24.534506  24.810369   531500

# %%
spy = SPY['Close']['SPY'].to_frame()

# %%
spy
# Out:
#                    SPY
# Date
# 1993-01-29   24.241417
# 1993-02-01   24.413824
# 1993-02-02   24.465553
# 1993-02-03   24.724165
# 1993-02-04   24.827610
# ...                ...
# 2024-12-24  594.320801
# 2024-12-26  594.360413
# 2024-12-27  588.103821
# 2024-12-30  581.392639
# 2024-12-31  579.277405
#
# [8038 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy_roll=spy.rolling(window=10)
spy_roll=spy_roll.mean()
spy_roll
# Out:
#                    SPY
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-12-24  590.319135
# 2024-12-26  589.915637
# 2024-12-27  589.194824
# 2024-12-30  587.814703
# 2024-12-31  585.968915
#
# [8038 rows x 1 columns]

# %%
spy.rolling(window=10, min_periods=5).max().head(15)
# Out:
#                   SPY
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04  24.827610
# 1993-02-05  24.827610
# 1993-02-08  24.827610
# 1993-02-09  24.827610
# 1993-02-10  24.827610
# 1993-02-11  24.827610
# 1993-02-12  24.827610
# 1993-02-16  24.827610
# 1993-02-17  24.827610
# 1993-02-18  24.827610
# 1993-02-19  24.810368

# %%
spy
# Out:
#                    SPY
# Date
# 1993-01-29   24.241417
# 1993-02-01   24.413824
# 1993-02-02   24.465553
# 1993-02-03   24.724165
# 1993-02-04   24.827610
# ...                ...
# 2024-12-24  594.320801
# 2024-12-26  594.360413
# 2024-12-27  588.103821
# 2024-12-30  581.392639
# 2024-12-31  579.277405
#
# [8038 rows x 1 columns]

# %%
spy
# Out:
#                    SPY
# Date
# 1993-01-29   24.241417
# 1993-02-01   24.413824
# 1993-02-02   24.465553
# 1993-02-03   24.724165
# 1993-02-04   24.827610
# ...                ...
# 2024-12-24  594.320801
# 2024-12-26  594.360413
# 2024-12-27  588.103821
# 2024-12-30  581.392639
# 2024-12-31  579.277405
#
# [8038 rows x 1 columns]

# %%
spy_close = SPY['Close', 'SPY'].to_frame()

# %%
spy_close
# Out:
#                  Close
#                    SPY
# Date
# 1993-01-29   24.241417
# 1993-02-01   24.413824
# 1993-02-02   24.465553
# 1993-02-03   24.724165
# 1993-02-04   24.827610
# ...                ...
# 2024-12-24  594.320801
# 2024-12-26  594.360413
# 2024-12-27  588.103821
# 2024-12-30  581.392639
# 2024-12-31  579.277405
#
# [8038 rows x 1 columns]

# %%
spy["SMA50"]=spy_close.rolling(window=50, min_periods= 50).mean()

# %%
spy
# Out:
#                    SPY       SMA50
# Date
# 1993-01-29   24.241417         NaN
# 1993-02-01   24.413824         NaN
# 1993-02-02   24.465553         NaN
# 1993-02-03   24.724165         NaN
# 1993-02-04   24.827610         NaN
# ...                ...         ...
# 2024-12-24  594.320801  583.270122
# 2024-12-26  594.360413  583.734763
# 2024-12-27  588.103821  584.024625
# 2024-12-30  581.392639  584.179279
# 2024-12-31  579.277405  584.247495
#
# [8038 rows x 2 columns]

# %%
spy["SMA200"]=spy_close.rolling(window=200, min_periods= 200).mean() #Moving average for 200

# %%
spy
# Out:
#                    SPY       SMA50      SMA200
# Date
# 1993-01-29   24.241417         NaN         NaN
# 1993-02-01   24.413824         NaN         NaN
# 1993-02-02   24.465553         NaN         NaN
# 1993-02-03   24.724165         NaN         NaN
# 1993-02-04   24.827610         NaN         NaN
# ...                ...         ...         ...
# 2024-12-24  594.320801  583.270122  542.276925
# 2024-12-26  594.360413  583.734763  542.727162
# 2024-12-27  588.103821  584.024625  543.150069
# 2024-12-30  581.392639  584.179279  543.544398
# 2024-12-31  579.277405  584.247495  543.945403
#
# [8038 rows x 3 columns]

# %%
spy.plot(figsize=(15,8), fontsize=12)
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %%
spy["EMA100"]=spy.SPY.ewm(span=100, min_periods=100).mean()

# %%
spy
# Out:
#                    SPY       SMA50      SMA200      EMA100
# Date
# 1993-01-29   24.241417         NaN         NaN         NaN
# 1993-02-01   24.413824         NaN         NaN         NaN
# 1993-02-02   24.465553         NaN         NaN         NaN
# 1993-02-03   24.724165         NaN         NaN         NaN
# 1993-02-04   24.827610         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2024-12-24  594.320801  583.270122  542.276925  568.703941
# 2024-12-26  594.360413  583.734763  542.727162  569.211990
# 2024-12-27  588.103821  584.024625  543.150069  569.586086
# 2024-12-30  581.392639  584.179279  543.544398  569.819879
# 2024-12-31  579.277405  584.247495  543.945403  570.007156
#
# [8038 rows x 4 columns]

# %%
spy.plot(figsize=(15,8), fontsize=12)
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %%
spy['Day']=spy.index.day_name()
spy["Quarter"]= spy.index.quarter

# %%
spy
# Out:
#                    SPY       SMA50      SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   24.241417         NaN         NaN         NaN     Friday        1
# 1993-02-01   24.413824         NaN         NaN         NaN     Monday        1
# 1993-02-02   24.465553         NaN         NaN         NaN    Tuesday        1
# 1993-02-03   24.724165         NaN         NaN         NaN  Wednesday        1
# 1993-02-04   24.827610         NaN         NaN         NaN   Thursday        1
# ...                ...         ...         ...         ...        ...      ...
# 2024-12-24  594.320801  583.270122  542.276925  568.703941    Tuesday        4
# 2024-12-26  594.360413  583.734763  542.727162  569.211990   Thursday        4
# 2024-12-27  588.103821  584.024625  543.150069  569.586086     Friday        4
# 2024-12-30  581.392639  584.179279  543.544398  569.819879     Monday        4
# 2024-12-31  579.277405  584.247495  543.945403  570.007156    Tuesday        4
#
# ...

# %%
SPY = yf.download("SPY", start="1993-01-01", end="2024-12-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SPY
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 1993-01-29   24.241407   24.258649   24.137959   24.258649   1003200
# 1993-02-01   24.413815   24.413815   24.258642   24.258642    480500
# 1993-02-02   24.465544   24.482785   24.344854   24.396578    201300
# 1993-02-03   24.724159   24.741401   24.482780   24.500021    529400
# 1993-02-04   24.827602   24.879327   24.534499   24.810361    531500
# ...                ...         ...         ...         ...       ...
# 2024-12-23  587.787476  588.390381  580.839043  584.031594  57635800
# 2024-12-24  594.320801  594.360375  588.558452  589.141630  33160100
# 2024-12-26  594.360352  595.487074  591.138180  592.541682  41219100
# 2024-12-27  588.103821  590.841689  583.903150  590.604424  64969300
# 2024-12-30  581.392517  584.871680  577.626742  581.066391  56578800
#
# [8037 rows x 5 columns]

# %%
spy = SPY["Close"]

# %%
spy
# Out:
# Ticker             SPY
# Date
# 1993-01-29   24.241407
# 1993-02-01   24.413815
# 1993-02-02   24.465544
# 1993-02-03   24.724159
# 1993-02-04   24.827602
# ...                ...
# 2024-12-23  587.787476
# 2024-12-24  594.320801
# 2024-12-26  594.360352
# 2024-12-27  588.103821
# 2024-12-30  581.392517
#
# [8037 rows x 1 columns]

# %%
# If spy is already a DataFrame, you don't need to call to_frame()
# You can use it directly as a DataFrame

# If you need to ensure spy is a DataFrame, you can check its type first:
if not isinstance(spy, pd.DataFrame):
    spy = spy.to_frame()
# Otherwise, just use spy as is

# If spy was actually a Series and you intended to convert it to DataFrame:
# spy = spy.to_frame()

# %%
spy
# Out:
# Ticker             SPY
# Date
# 1993-01-29   24.241407
# 1993-02-01   24.413815
# 1993-02-02   24.465544
# 1993-02-03   24.724159
# 1993-02-04   24.827602
# ...                ...
# 2024-12-23  587.787476
# 2024-12-24  594.320801
# 2024-12-26  594.360352
# 2024-12-27  588.103821
# 2024-12-30  581.392517
#
# [8037 rows x 1 columns]

# %%
all_days = pd.date_range(start="2010-01-01",end="2020-01-01", freq="D")
all_days
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#                '2010-01-09', '2010-01-10',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3653, freq='D')

# %%
spy = spy.reindex(all_days)
spy
# Out:
# Ticker             SPY
# 2010-01-01         NaN
# 2010-01-02         NaN
# 2010-01-03         NaN
# 2010-01-04   85.027946
# 2010-01-05   85.253036
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  294.225983
# 2019-12-31  294.940674
# 2020-01-01         NaN
#
# [3653 rows x 1 columns]

# %%
spy.fillna(method="bfill", inplace=True)
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_24340\502726889.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method="bfill", inplace=True)

# %%
spy.bfill()
# Out:
# Ticker             SPY
# 2010-01-01   85.027946
# 2010-01-02   85.027946
# 2010-01-03   85.027946
# 2010-01-04   85.027946
# 2010-01-05   85.253036
# ...                ...
# 2019-12-28  294.225983
# 2019-12-29  294.225983
# 2019-12-30  294.225983
# 2019-12-31  294.940674
# 2020-01-01         NaN
#
# [3653 rows x 1 columns]

# %%
SPY = yf.download("SPY",start="1993-01-01",end="2025-10-07", interval="1wk")#download in intervals of one week
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SPY
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 1993-01-25   24.241400   24.258641   24.137951   24.258641    1003200
# 1993-02-01   24.810377   24.879343   24.258652   24.258652    2234800
# 1993-02-08   24.603474   24.896577   24.568991   24.810370    1159800
# 1993-02-15   24.034512   24.534512   23.620718   24.534512     998700
# 1993-02-22   24.500032   24.517274   23.982790   24.103480    1024300
# ...                ...         ...         ...         ...        ...
# 2025-09-08  653.660889  655.351206  643.528998  644.921038  350016000
# 2025-09-15  659.915039  661.098255  650.568621  655.878195  415298400
# 2025-09-22  659.870178  665.373935  652.481975  660.249064  378044600
# 2025-09-29  667.238403  670.698151  659.660758  662.402656  359722800
# 2025-10-06  667.148621  671.007214  665.702880  669.641255  126643400
#
# [1707 rows x 5 columns]

# %% [markdown]
# Cumulative returns and Drawdown

# %%
pip install --upgrade yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
apple = yf.download("AAPL", period="max")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 1980-12-12    0.098390    0.098817    0.098390    0.098390  469033600
# 1980-12-15    0.093256    0.093684    0.093256    0.093684  175884800
# 1980-12-16    0.086412    0.086839    0.086412    0.086839  105728000
# 1980-12-17    0.088550    0.088978    0.088550    0.088550   86441600
# 1980-12-18    0.091118    0.091545    0.091118    0.091118   73449600
# ...                ...         ...         ...         ...        ...
# 2026-01-21  247.649994  251.559998  245.179993  248.699997   54641700
# 2026-01-22  248.350006  251.000000  248.149994  249.199997   39708300
# 2026-01-23  248.039993  249.410004  244.679993  247.320007   41689000
# 2026-01-26  255.410004  256.559998  249.800003  251.479996   55969200
# 2026-01-27  259.290009  261.950012  258.660004  259.140015   33684813
#
# [11372 rows x 5 columns]

# %%
apple = apple.Close

# %%
apple
# Out:
# Ticker            AAPL
# Date
# 1980-12-12    0.098390
# 1980-12-15    0.093256
# 1980-12-16    0.086412
# 1980-12-17    0.088550
# 1980-12-18    0.091118
# ...                ...
# 2026-01-21  247.649994
# 2026-01-22  248.350006
# 2026-01-23  248.039993
# 2026-01-26  255.410004
# 2026-01-27  259.290009
#
# [11372 rows x 1 columns]

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_24340\1324972174.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apple["d_returns"]=np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
# Ticker            AAPL  d_returns
# Date
# 1980-12-12    0.098390        NaN
# 1980-12-15    0.093256  -0.053581
# 1980-12-16    0.086412  -0.076231
# 1980-12-17    0.088550   0.024450
# 1980-12-18    0.091118   0.028580
# ...                ...        ...
# 2026-01-21  247.649994   0.003843
# 2026-01-22  248.350006   0.002823
# 2026-01-23  248.039993  -0.001249
# 2026-01-26  255.410004   0.029280
# 2026-01-27  259.290009   0.015077
#
# [11372 rows x 2 columns]

# %%
apple = apple.copy()
apple.dropna(inplace=True)

# %%
apple
# Out:
# Ticker            AAPL  d_returns
# Date
# 1980-12-15    0.093256  -0.053581
# 1980-12-16    0.086412  -0.076231
# 1980-12-17    0.088550   0.024450
# 1980-12-18    0.091118   0.028580
# 1980-12-19    0.096678   0.059239
# ...                ...        ...
# 2026-01-21  247.649994   0.003843
# 2026-01-22  248.350006   0.002823
# 2026-01-23  248.039993  -0.001249
# 2026-01-26  255.410004   0.029280
# 2026-01-27  259.290009   0.015077
#
# [11371 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# np.float64(7.87676828288433)

# %%
np.exp(apple.d_returns.sum())
# Out:
# np.float64(2635.342102935614)

# %%
apple["cumreturns"] = apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
# Ticker            AAPL  d_returns   cumreturns
# Date
# 1980-12-15    0.093256  -0.053581     0.947829
# 1980-12-16    0.086412  -0.076231     0.878261
# 1980-12-17    0.088550   0.024450     0.899998
# 1980-12-18    0.091118   0.028580     0.926092
# 1980-12-19    0.096678   0.059239     0.982609
# ...                ...        ...          ...
# 2026-01-21  247.649994   0.003843  2517.036655
# 2026-01-22  248.350006   0.002823  2524.151359
# 2026-01-23  248.039993  -0.001249  2521.000486
# 2026-01-26  255.410004   0.029280  2595.906954
# 2026-01-27  259.290009   0.015077  2635.342103
#
# [11371 rows x 3 columns]

# %%
apple.cumreturns.plot(figsize=(15,8), title="Apple buy and Hold", fontsize = 12)
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# np.float64(0.17456209720225585)

# %%
apple.d_returns.std()*np.sqrt(252)# standard deviation
# Out:
# np.float64(0.4450160454892619)

# %%
# how to calculate drawdowns

# %%
apple["cummax"]=apple.cumreturns.cummax()

# %%
apple
# Out:
# Ticker            AAPL  d_returns   cumreturns       cummax
# Date
# 1980-12-15    0.093256  -0.053581     0.947829     0.947829
# 1980-12-16    0.086412  -0.076231     0.878261     0.947829
# 1980-12-17    0.088550   0.024450     0.899998     0.947829
# 1980-12-18    0.091118   0.028580     0.926092     0.947829
# 1980-12-19    0.096678   0.059239     0.982609     0.982609
# ...                ...        ...          ...          ...
# 2026-01-21  247.649994   0.003843  2517.036655  2908.745181
# 2026-01-22  248.350006   0.002823  2524.151359  2908.745181
# 2026-01-23  248.039993  -0.001249  2521.000486  2908.745181
# 2026-01-26  255.410004   0.029280  2595.906954  2908.745181
# 2026-01-27  259.290009   0.015077  2635.342103  2908.745181
#
# [11371 rows x 4 columns]

# %%
apple[["cumreturns","cummax"]].plot(figsize=(15,8),title="Apple Buy and Hold + Cummax", fontsize=12)
plt.show()

# %%
apple["drawdown"]=apple["cummax"]-apple["cumreturns"]
apple
# Out:
# Ticker            AAPL  d_returns   cumreturns       cummax    drawdown
# Date
# 1980-12-15    0.093256  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.086412  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.088550   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.091118   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.096678   0.059239     0.982609     0.982609    0.000000
# ...                ...        ...          ...          ...         ...
# 2026-01-21  247.649994   0.003843  2517.036655  2908.745181  391.708526
# 2026-01-22  248.350006   0.002823  2524.151359  2908.745181  384.593823
# 2026-01-23  248.039993  -0.001249  2521.000486  2908.745181  387.744695
# 2026-01-26  255.410004   0.029280  2595.906954  2908.745181  312.838228
# 2026-01-27  259.290009   0.015077  2635.342103  2908.745181  273.403078
#
# [11371 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 874.2939185873722

# %%
apple.drawdown.idxmax()# show the day
# Out:
# Timestamp('2025-04-08 00:00:00')

# %%
apple.loc[(apple.index=="2025-04-08")]
# Out:
# Ticker            AAPL  d_returns   cumreturns       cummax    drawdown
# Date
# 2025-04-08  171.832413  -0.051102  1746.450603  2620.744522  874.293919

# %%
apple["Drawdown %"] = (apple["cummax"]-apple["cumreturns"])/(apple["cummax"])

# %%
apple
# Out:
# Ticker            AAPL  d_returns   cumreturns       cummax    drawdown  \
# Date
# 1980-12-15    0.093256  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.086412  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.088550   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.091118   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.096678   0.059239     0.982609     0.982609    0.000000
# ...                ...        ...          ...          ...         ...
# 2026-01-21  247.649994   0.003843  2517.036655  2908.745181  391.708526
# 2026-01-22  248.350006   0.002823  2524.151359  2908.745181  384.593823
# 2026-01-23  248.039993  -0.001249  2521.000486  2908.745181  387.744695
# 2026-01-26  255.410004   0.029280  2595.906954  2908.745181  312.838228
# 2026-01-27  259.290009   0.015077  2635.342103  2908.745181  273.403078
#
# Ticker      Drawdown %
# Date
# 1980-12-15    0.000000
# 1980-12-16    0.073398
# ...

# %%
apple["Drawdown %"].max()
# Out:
# 0.8180144407516777

# %%
apple["Drawdown %"].idxmax()
# Out:
# Timestamp('2003-04-17 00:00:00')

# %%
apple.loc[(apple.index<="2025-04-08")]
# Out:
# Ticker            AAPL  d_returns   cumreturns       cummax    drawdown  \
# Date
# 1980-12-15    0.093256  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.086412  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.088550   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.091118   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.096678   0.059239     0.982609     0.982609    0.000000
# ...                ...        ...          ...          ...         ...
# 2025-04-02  223.127014   0.003131  2267.792801  2620.744522  352.951721
# 2025-04-03  202.497543  -0.097013  2058.121347  2620.744522  562.623175
# 2025-04-04  187.738037  -0.075680  1908.110368  2620.744522  712.634154
# 2025-04-07  180.841614  -0.037426  1838.017290  2620.744522  782.727232
# 2025-04-08  171.832413  -0.051102  1746.450603  2620.744522  874.293919
#
# Ticker      Drawdown %
# Date
# 1980-12-15    0.000000
# 1980-12-16    0.073398
# ...

# %% [markdown]
# ##SMA Strategy

# %%
apple.loc[(apple.index>="1991-01-01")]
# Out:
# Ticker            AAPL  d_returns   cumreturns       cummax    drawdown  \
# Date
# 1991-01-02    0.308517   0.011560     3.135674     4.133357    0.997683
# 1991-01-03    0.304971  -0.011560     3.099634     4.133357    1.033723
# 1991-01-04    0.306744   0.005797     3.117654     4.133357    1.015703
# 1991-01-07    0.306744   0.000000     3.117654     4.133357    1.015703
# 1991-01-08    0.306744   0.000000     3.117654     4.133357    1.015703
# ...                ...        ...          ...          ...         ...
# 2026-01-21  247.649994   0.003843  2517.036655  2908.745181  391.708526
# 2026-01-22  248.350006   0.002823  2524.151359  2908.745181  384.593823
# 2026-01-23  248.039993  -0.001249  2521.000486  2908.745181  387.744695
# 2026-01-26  255.410004   0.029280  2595.906954  2908.745181  312.838228
# 2026-01-27  259.290009   0.015077  2635.342103  2908.745181  273.403078
#
# Ticker      Drawdown %
# Date
# 1991-01-02    0.241373
# 1991-01-03    0.250093
# ...

# %%
data = apple.AAPL.loc[(apple.index>="1991-01-01")]

# %%
data
# Out:
# Date
# 1991-01-02      0.308517
# 1991-01-03      0.304971
# 1991-01-04      0.306744
# 1991-01-07      0.306744
# 1991-01-08      0.306744
#                  ...
# 2026-01-21    247.649994
# 2026-01-22    248.350006
# 2026-01-23    248.039993
# 2026-01-26    255.410004
# 2026-01-27    259.290009
# Name: AAPL, Length: 8831, dtype: float64

# %%
data = data.to_frame()

# %%
data
# Out:
#                   AAPL
# Date
# 1991-01-02    0.308517
# 1991-01-03    0.304971
# 1991-01-04    0.306744
# 1991-01-07    0.306744
# 1991-01-08    0.306744
# ...                ...
# 2026-01-21  247.649994
# 2026-01-22  248.350006
# 2026-01-23  248.039993
# 2026-01-26  255.410004
# 2026-01-27  259.290009
#
# [8831 rows x 1 columns]

# %%
sma_s=50
sma_l= 100

# %%
data["sma_s"]=data.AAPL.rolling(sma_s).mean()
data["sma_l"]=data.AAPL.rolling(sma_l).mean()

# %%
data
# Out:
#                   AAPL       sma_s       sma_l
# Date
# 1991-01-02    0.308517         NaN         NaN
# 1991-01-03    0.304971         NaN         NaN
# 1991-01-04    0.306744         NaN         NaN
# 1991-01-07    0.306744         NaN         NaN
# 1991-01-08    0.306744         NaN         NaN
# ...                ...         ...         ...
# 2026-01-21  247.649994  270.593398  260.941898
# 2026-01-22  248.350006  270.196198  261.102050
# 2026-01-23  248.039993  269.768398  261.263298
# 2026-01-26  255.410004  269.371599  261.522423
# 2026-01-27  259.290009  269.087999  261.732933
#
# [8831 rows x 3 columns]

# %%
data.plot(figsize= (12,8), title = "AAPLE - SMA {} | SMA{}".format(sma_s,sma_l), fontsize= 12)
plt.show()

# %%
data.loc["2016"].plot(figsize= (12,8), title = "AAPLE - SMA {} | SMA{}".format(sma_s,sma_l), fontsize= 12)
plt.show()

# %%
data.dropna(inplace= True)
data
# Out:
#                   AAPL       sma_s       sma_l
# Date
# 1991-05-23    0.321537    0.425472    0.408400
# 1991-05-24    0.326880    0.422734    0.408584
# 1991-05-28    0.327771    0.419873    0.408812
# 1991-05-29    0.334897    0.416940    0.409093
# 1991-05-30    0.339350    0.413848    0.409419
# ...                ...         ...         ...
# 2026-01-21  247.649994  270.593398  260.941898
# 2026-01-22  248.350006  270.196198  261.102050
# 2026-01-23  248.039993  269.768398  261.263298
# 2026-01-26  255.410004  269.371599  261.522423
# 2026-01-27  259.290009  269.087999  261.732933
#
# [8732 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)
data
# Out:
#                   AAPL       sma_s       sma_l  position
# Date
# 1991-05-23    0.321537    0.425472    0.408400         1
# 1991-05-24    0.326880    0.422734    0.408584         1
# 1991-05-28    0.327771    0.419873    0.408812         1
# 1991-05-29    0.334897    0.416940    0.409093         1
# 1991-05-30    0.339350    0.413848    0.409419         1
# ...                ...         ...         ...       ...
# 2026-01-21  247.649994  270.593398  260.941898         1
# 2026-01-22  248.350006  270.196198  261.102050         1
# 2026-01-23  248.039993  269.768398  261.263298         1
# 2026-01-26  255.410004  269.371599  261.522423         1
# 2026-01-27  259.290009  269.087999  261.732933         1
#
# [8732 rows x 4 columns]

# %%
data.loc[:,["sma_s","sma_l","position"]].plot(figsize= (12,8), title = "AAPLE - SMA {} | SMA{}".format(sma_s,sma_l), fontsize= 12)
plt.show()

# %%
data.loc[:,["sma_s","sma_l","position"]].plot(figsize= (12,8), title = "AAPLE - SMA {} | SMA{}".format(sma_s,sma_l), fontsize= 12, secondary_y="position")
plt.show()

# %%
data.loc["2016",["sma_s","sma_l","position"]].plot(figsize= (12,8), title = "AAPLE - SMA {} | SMA{}".format(sma_s,sma_l), fontsize= 12, secondary_y="position")
plt.show()

# %%
data["returnb&h"]=np.log(data.AAPL.div(data.AAPL.shift(1)))

# %%
data["strategy"]=data["returnb&h"]*data.position.shift(1)

# %%
data
# Out:
#                   AAPL       sma_s       sma_l  position  returnb&h  strategy
# Date
# 1991-05-23    0.321537    0.425472    0.408400         1        NaN       NaN
# 1991-05-24    0.326880    0.422734    0.408584         1   0.016483  0.016483
# 1991-05-28    0.327771    0.419873    0.408812         1   0.002721  0.002721
# 1991-05-29    0.334897    0.416940    0.409093         1   0.021507  0.021507
# 1991-05-30    0.339350    0.413848    0.409419         1   0.013210  0.013210
# ...                ...         ...         ...       ...        ...       ...
# 2026-01-21  247.649994  270.593398  260.941898         1   0.003843  0.003843
# 2026-01-22  248.350006  270.196198  261.102050         1   0.002823  0.002823
# 2026-01-23  248.039993  269.768398  261.263298         1  -0.001249 -0.001249
# 2026-01-26  255.410004  269.371599  261.522423         1   0.029280  0.029280
# 2026-01-27  259.290009  269.087999  261.732933         1   0.015077  0.015077
#
# [8732 rows x 6 columns]

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                   AAPL       sma_s       sma_l  position  returnb&h  strategy
# Date
# 1991-05-24    0.326880    0.422734    0.408584         1   0.016483  0.016483
# 1991-05-28    0.327771    0.419873    0.408812         1   0.002721  0.002721
# 1991-05-29    0.334897    0.416940    0.409093         1   0.021507  0.021507
# 1991-05-30    0.339350    0.413848    0.409419         1   0.013210  0.013210
# 1991-05-31    0.334897    0.410916    0.409701         1  -0.013210 -0.013210
# ...                ...         ...         ...       ...        ...       ...
# 2026-01-21  247.649994  270.593398  260.941898         1   0.003843  0.003843
# 2026-01-22  248.350006  270.196198  261.102050         1   0.002823  0.002823
# 2026-01-23  248.039993  269.768398  261.263298         1  -0.001249 -0.001249
# 2026-01-26  255.410004  269.371599  261.522423         1   0.029280  0.029280
# 2026-01-27  259.290009  269.087999  261.732933         1   0.015077  0.015077
#
# [8731 rows x 6 columns]

# %%
data[["returnb&h","strategy"]].sum()
# Out:
# returnb&h    6.692591
# strategy     1.689993
# dtype: float64

# %%
data[["returnb&h","strategy"]].sum().apply(np.exp) #what 1 dollar will be if invested
# Out:
# returnb&h    806.408851
# strategy       5.419440
# dtype: float64

# %%
data[["returnb&h","strategy"]].std()*np.sqrt(252)#annual std
# Out:
# returnb&h    0.427098
# strategy     0.427260
# dtype: float64

# %% [markdown]
# ## Strategy adjusted with long bias

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["strategy2"]=data["returnb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)
data
# Out:
#                   AAPL       sma_s       sma_l  position  returnb&h  strategy  \
# Date
# 1991-05-28    0.327771    0.419873    0.408812         1   0.002721  0.002721
# 1991-05-29    0.334897    0.416940    0.409093         1   0.021507  0.021507
# 1991-05-30    0.339350    0.413848    0.409419         1   0.013210  0.013210
# 1991-05-31    0.334897    0.410916    0.409701         1  -0.013210 -0.013210
# 1991-06-03    0.350929    0.408730    0.410001        -1   0.046761  0.046761
# ...                ...         ...         ...       ...        ...       ...
# 2026-01-21  247.649994  270.593398  260.941898         1   0.003843  0.003843
# 2026-01-22  248.350006  270.196198  261.102050         1   0.002823  0.002823
# 2026-01-23  248.039993  269.768398  261.263298         1  -0.001249 -0.001249
# 2026-01-26  255.410004  269.371599  261.522423         1   0.029280  0.029280
# 2026-01-27  259.290009  269.087999  261.732933         1   0.015077  0.015077
#
# ...

# %%
data[["returnb&h","strategy2"]].sum()
# Out:
# returnb&h    6.676108
# strategy2    4.174809
# dtype: float64

# %%
data[["returnb&h","strategy2"]].sum().apply(np.exp) #what 1 dollar will be if invested
# Out:
# returnb&h    793.225867
# strategy2     65.027407
# dtype: float64

# %%
data[["returnb&h","strategy2"]].std()*np.sqrt(252)#annual std
# Out:
# returnb&h    0.427114
# strategy2    0.329481
# dtype: float64

# %%
## Strategy 2 is better than strategy 1
data[["strategy","strategy2"]].std()*np.sqrt(252)#annual std
# Out:
# strategy     0.427276
# strategy2    0.329481
# dtype: float64

# %% [markdown]
# ##find SMA for the 5 best stocks
# ##Create a bias strategy
# ##Compare strategy
# ## Pick the best 3 stocks for the ball

# %% [markdown]
# ## Creating our first function

# %%
def test_strategy(stock,start,end,SMA):
    df = yf.download(stock,start=start,end=end)
    if isinstance(df.Close, pd.Series):
        data = df.Close.to_frame(name="Close")
    else:
        data = df[["Close"]].copy()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]= data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)

    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"]=data["returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret =np.exp(data["strategy"].sum())
    std = data["strategy"].std()*np.sqrt(252)

    return ret,std

# %%
test_strategy("SPY","2000-01-01","2020-01-01", (50,100))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (np.float64(3.7607112513594636), np.float64(0.18733821067331094))

# %% [markdown]
# ## Creating our first Class

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S,SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
    def get_data(self):
        df = yf.download(self.symbol,start=self.start,end=self.end)
        if isinstance(df.Close, pd.Series):
            data = df.Close.to_frame(name="Close")
        else:
            data = df[["Close"]].copy()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]= data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data

        return data
    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnsstrategy"].iloc[-1]
        outperf=perf-data["returnsbh"].iloc[-1]
        self.results=data
        
        ret =np.exp(data["strategy"].sum())
        std = data["strategy"].std()*np.sqrt(252)
        
        return round(perf,6), round(outperf,6)
    def plot_results(self):
        if self.results is None:
            print("Run the test please !")
        else:
            title="{}| SMA_S={} | SMA_L={}".format(self.symbol,self.SMA_S,self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title, figsize=(12,8))
            plt.ylabel("Growth of $1")
            plt.xlabel("Date")
            plt.legend(["Buy & Hold", "SMA Strategy"])
            plt.show()

# %%
tester = SMABacktester("SPY",50,100,"2000-01-01", "2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (np.float64(3.760711), np.float64(0.430822))

# %%
tester.plot_results()

# %% [markdown]
# ## !. Watch the Stan Estien Strategy and apply it on Trading View
# ## Create the strategy in python
# ## Backtest
# ## Save it as a python file
