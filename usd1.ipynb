# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2015-01-01" , end = "2025-01-01")# downloading the data for apple AAPL is the trade mark for apple.
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_8696\472372654.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Apple = yf.download("AAPL", start = "2015-01-01" , end = "2025-01-01")# downloading the data for apple AAPL is the trade mark for apple.
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2015-01-02   24.261042   24.729265   23.821666   24.718169  212818400
# 2015-01-05   23.577570   24.110146   23.391169   24.030260  257142000
# 2015-01-06   23.579796   23.839426   23.218087   23.641929  263188400
# 2015-01-07   23.910431   24.010288   23.677428   23.788382  160423600
# 2015-01-08   24.829128   24.886824   24.121246   24.238858  237458000
# ...                ...         ...         ...         ...        ...
# 2024-12-24  257.286682  257.296626  254.386957  254.586262   23234700
# 2024-12-26  258.103729  259.179926  256.718662  257.276679   27237100
# 2024-12-27  254.685867  257.784882  252.164818  256.917934   42355300
# 2024-12-30  251.307877  252.603281  249.863009  251.337769   35557500
# 2024-12-31  249.534180  252.384064  248.547676  251.547039   39480700
#
# [2516 rows x 5 columns]

# %%
ticker = ["SPY","AAPL","kO"]

# %%
stocks = yf.download(ticker, start = "2015-01-01" , end = "2025-01-01") # this is downloading the multiple stocks
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_8696\1368731124.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks = yf.download(ticker, start = "2015-01-01" , end = "2025-01-01") # this is downloading the multiple stocks
# [*********************100%***********************]  3 of 3 completed

# %%
stocks
# Out:
# Price            Close                               High             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2015-01-02   24.261042  30.222618  171.568054   24.729265  30.409090
# 2015-01-05   23.577570  30.222618  168.469559   24.110146  30.817892
# 2015-01-06   23.579796  30.452126  166.882782   23.839426  30.796379
# 2015-01-07   23.910431  30.832228  168.962280   24.010288  30.918290
# 2015-01-08   24.829128  31.205170  171.960571   24.886824  31.248202
# ...                ...        ...         ...         ...        ...
# 2024-12-24  257.286682  61.939281  597.729492  257.296626  61.939281
# 2024-12-26  258.103729  61.673149  597.769348  259.179926  61.840714
# 2024-12-27  254.685867  61.554871  591.476868  257.784882  62.047704
# 2024-12-30  251.307877  61.140888  584.727173  252.603281  61.446446
# 2024-12-31  249.534180  61.367588  582.599915  252.384064  61.535153
#
# Price                          Low                               Open  \
# Ticker             SPY        AAPL         KO         SPY        AAPL
# Date
# 2015-01-02  172.779054   23.821666  29.978772  170.524097   24.718169
# 2015-01-05  170.682742   23.391169  30.179588  168.160552   24.030260
# 2015-01-06  169.304757   23.218087  30.294344  166.081017   23.641929
# 2015-01-07  169.304701   23.677428  30.538178  167.768000   23.788382
# 2015-01-08  172.177722   24.121246  30.911120  170.365415   24.238858
# ...                ...         ...        ...         ...         ...
# 2024-12-24  597.769293  254.386957  61.121176  591.934094  254.586262
# 2024-12-26  598.902533  256.718662  61.505588  594.528696  257.276679
# 2024-12-27  594.230439  252.164818  61.318309  587.252104  256.917934
# 2024-12-30  588.226291  249.863009  60.795906  580.939799  251.337769
# 2024-12-31  587.132835  248.547676  60.914182  580.949738  251.547039
#
# Price                                 Volume
# Ticker             KO         SPY       AAPL        KO        SPY
# Date
# 2015-01-02  30.308681  172.361472  212818400   9921100  121465900
# 2015-01-05  30.617075  170.515711  257142000  26292600  169632600
# 2015-01-06  30.416266  168.778599  263188400  16897500  209151400
# 2015-01-07  30.695959  168.218984  160423600  13412300  125346700
# 2015-01-08  30.968497  170.382109  237458000  21743600  147217800
# ...               ...         ...        ...       ...        ...
# 2024-12-24  61.308456  592.520617   23234700   5019100   33160100
# 2024-12-26  61.722432  595.940247   27237100   7943800   41219100
# 2024-12-27  61.554871  593.991813   42355300   8542800   64969300
# 2024-12-30  61.446446  584.399176   35557500   8972200   56578800
# 2024-12-31  61.131030  586.407129   39480700   9256700   57052700
#
# [2516 rows x 15 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2015-01-02 to 2024-12-31
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   2516 non-null   float64
#  1   (Close, KO)     2516 non-null   float64
#  2   (Close, SPY)    2516 non-null   float64
#  3   (High, AAPL)    2516 non-null   float64
#  4   (High, KO)      2516 non-null   float64
#  5   (High, SPY)     2516 non-null   float64
#  6   (Low, AAPL)     2516 non-null   float64
#  7   (Low, KO)       2516 non-null   float64
#  8   (Low, SPY)      2516 non-null   float64
#  9   (Open, AAPL)    2516 non-null   float64
#  10  (Open, KO)      2516 non-null   float64
#  11  (Open, SPY)     2516 non-null   float64
#  12  (Volume, AAPL)  2516 non-null   int64
#  13  (Volume, KO)    2516 non-null   int64
#  14  (Volume, SPY)   2516 non-null   int64
# dtypes: float64(12), int64(3)
# memory usage: 314.5 KB

# %%
stocks.to_csv("stocksticker")# using to_csv function to downloaded the stock data

# %%
stocks = pd.read_csv("stocksticker") # read the downloaded csv  file

# %%
stocks
# Out:
#            Price               Close             Close.1             Close.2  \
# 0         Ticker                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2015-01-02   24.26104164123535  30.222618103027344  171.56805419921875
# 3     2015-01-05   23.57756996154785  30.222618103027344   168.4695587158203
# 4     2015-01-06  23.579795837402344  30.452125549316406  166.88278198242188
# ...          ...                 ...                 ...                 ...
# 2513  2024-12-24  257.28668212890625   61.93928146362305      597.7294921875
# 2514  2024-12-26   258.1037292480469   61.67314910888672   597.7693481445312
# 2515  2024-12-27   254.6858673095703   61.55487060546875   591.4768676757812
# 2516  2024-12-30  251.30787658691406   61.14088821411133   584.7271728515625
# 2517  2024-12-31      249.5341796875   61.36758804321289   582.5999145507812
#
#                     High              High.1              High.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2     24.729264560959393   30.40909046617586  172.77905445134888
# 3     24.110145998105324  30.817891684615038  170.68274183915315
# 4     23.839426153600677    30.7963791206534  169.30475691705445
# ...                  ...                 ...                 ...
# 2513   257.2966260773909   61.93928146362305   597.7692934996265
# 2514   259.1799258751944  61.840714359600035   598.9025328618192
# 2515  257.78488174803636    62.0477038308768   594.2304389583717
# 2516  252.60328106925755  61.446446164838434   588.2262908200153
# 2517  252.38406352835983  61.535153285422325   587.1328351597793
#
#                      Low               Low.1               Low.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 
#
# Price                                 Volume
# Ticker             KO         SPY       AAPL        KO        SPY
# Date
# 2015-01-02  30.308681  172.361472  212818400   9921100  121465900
# 2015-01-05  30.617075  170.515711  257142000  26292600  169632600
# 2015-01-06  30.416266  168.778599  263188400  16897500  209151400
# 2015-01-07  30.695959  168.218984  160423600  13412300  125346700
# 2015-01-08  30.968497  170.382109  237458000  21743600  147217800
# ...               ...         ...        ...       ...        ...
# 2024-12-24  61.308456  592.520617   23234700   5019100   33160100
# 2024-12-26  61.722432  595.940247   27237100   7943800   41219100
# 2024-12-27  61.554871  593.991813   42355300   8542800   64969300
# 2024-12-30  61.446446  584.399176   35557500   8972200   56578800
# 2024-12-31  61.131030  586.407129   39480700   9256700   57052700
#
# [2516 rows x 15 columns]

# %%
stocks.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close',   'KO'),
#             ( 'Close',  'SPY'),
#             (  'High', 'AAPL'),
#             (  'High',   'KO'),
#             (  'High',  'SPY'),
#             (   'Low', 'AAPL'),
#             (   'Low',   'KO'),
#             (   'Low',  'SPY'),
#             (  'Open', 'AAPL'),
#             (  'Open',   'KO'),
#             (  'Open',  'SPY'),
#             ('Volume', 'AAPL'),
#             ('Volume',   'KO'),
#             ('Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
#convert multiindex to one tuple
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([ ('Close', 'AAPL'),    ('Close', 'KO'),   ('Close', 'SPY'),
#          ('High', 'AAPL'),     ('High', 'KO'),    ('High', 'SPY'),
#           ('Low', 'AAPL'),      ('Low', 'KO'),     ('Low', 'SPY'),
#          ('Open', 'AAPL'),     ('Open', 'KO'),    ('Open', 'SPY'),
#        ('Volume', 'AAPL'),   ('Volume', 'KO'),  ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2015-01-02      24.261042    30.222618    171.568054     24.729265
# 2015-01-05      23.577570    30.222618    168.469559     24.110146
# 2015-01-06      23.579796    30.452126    166.882782     23.839426
# 2015-01-07      23.910431    30.832228    168.962280     24.010288
# 2015-01-08      24.829128    31.205170    171.960571     24.886824
# ...                   ...          ...           ...           ...
# 2024-12-24     257.286682    61.939281    597.729492    257.296626
# 2024-12-26     258.103729    61.673149    597.769348    259.179926
# 2024-12-27     254.685867    61.554871    591.476868    257.784882
# 2024-12-30     251.307877    61.140888    584.727173    252.603281
# 2024-12-31     249.534180    61.367588    582.599915    252.384064
#
#             (High, KO)  (High, SPY)  (Low, AAPL)  (Low, KO)  (Low, SPY)  \
# Date
# 2015-01-02   30.409090   172.779054    23.821666  29.978772  170.524097
# 2015-01-05   30.817892   170.682742    23.391169  30.179588  168.160552
# 2015-01-06   30.796379   169.304757    23.218087  30.294344  166.081017
# 2015-01-07   30.918290   169.304701    23.677428  30.538178  167.768000
# 2015-01-08   31.248202   172.177722    24.121246  30.911120  170.365415
# 2024-12-27  594.230439  252.164818  61.318309  587.252104  256.917934
# 2024-12-30  588.226291  249.863009  60.795906  580.939799  251.337769
# 2024-12-31  587.132835  248.547676  60.914182  580.949738  251.547039
#
#                                       Volume
#                    KO         SPY       AAPL        KO        SPY
# Date
# 2015-01-02  30.308681  172.361472  212818400   9921100  121465900
# 2015-01-05  30.617075  170.515711  257142000  26292600  169632600
# 2015-01-06  30.416266  168.778599  263188400  16897500  209151400
# 2015-01-07  30.695959  168.218984  160423600  13412300  125346700
# 2015-01-08  30.968497  170.382109  237458000  21743600  147217800
# ...               ...         ...        ...       ...        ...
# 2024-12-24  61.308456  592.520617   23234700   5019100   33160100
# 2024-12-26  61.722432  595.940247   27237100   7943800   41219100
# 2024-12-27  61.554871  593.991813   42355300   8542800   64969300
# 2024-12-30  61.446446  584.399176   35557500   8972200   56578800
# 2024-12-31  61.131030  586.407129   39480700   9256700   57052700
#
# [2516 rows x 15 columns]

# %%
stocks.describe()
# Out:
#              Close                                   High               \
#               AAPL           KO          SPY         AAPL           KO
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# mean     93.949921    44.105249   312.093130    94.862311    44.402317
# std      65.504728    10.882425   115.143667    66.098727    10.956509
# min      20.624044    27.698988   155.869766    20.927682    28.086044
# 25%      35.257095    34.428001   213.389732    35.655401    34.686505
# 50%      64.450443    42.522947   274.781189    65.005715    42.902919
# 75%     150.379658    54.918729   401.621773   152.129382    55.409760
# max     258.103729    70.935501   602.174133   259.179926    71.440715
#
#                             Low                                   Open  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# mean    313.736123    92.935271    43.798871   310.206464    93.863012
# std     115.701454    64.817392    10.795595   114.501552    65.424438
# min     156.926746    20.425430    26.656353   153.758426    20.546432
# 25%     214.043092    34.878666    34.218009   212.639270    35.277314
# 50%     275.532315    63.647706    42.270407   273.766595    64.290829
# 75%     403.875985   148.411451    54.550563   398.938349   150.202232
# max     603.422460   256.718662    70.197094   601.391480   257.276679
#
#                                        Volume
#                 KO          SPY          AAPL            KO           SPY
# count  2516.000000  2516.000000  2.516000e+03  2.516000e+03  2.516000e+03
# mean     44.107231   312.047830  1.170853e+08  1.411074e+07  8.743599e+07
# std      10.880877   115.139702  6.839614e+07  6.139293e+06  4.490947e+07
# min      27.698984   155.426515  2.323470e+07  2.996300e+06  2.027000e+07
# 25%      34.456159   213.453525  7.105610e+07  1.032540e+07  5.893120e+07
# 50%      42.608491   274.804103  1.003646e+08  1.282735e+07  7.659475e+07
# 75%      54.952957   401.550895  1.426216e+08  1.598612e+07  1.022602e+08
# max      71.217255   602.055281  6.488252e+08  6.784570e+07  5.072443e+08

# %%
close = stocks.loc[:,'Close'].copy() # copy the details to close

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2015-01-02   24.261042  30.222618  171.568054
# 2015-01-05   23.577570  30.222618  168.469559
# 2015-01-06   23.579796  30.452126  166.882782
# 2015-01-07   23.910431  30.832228  168.962280
# 2015-01-08   24.829128  31.205170  171.960571
# ...                ...        ...         ...
# 2024-12-24  257.286682  61.939281  597.729492
# 2024-12-26  258.103729  61.673149  597.769348
# 2024-12-27  254.685867  61.554871  591.476868
# 2024-12-30  251.307877  61.140888  584.727173
# 2024-12-31  249.534180  61.367588  582.599915
#
# [2516 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
ax = close.plot(figsize=(12,6), fontsize = 12)
ax.set_title("Closing Prices for AAPL KO SPY")
ax.set_xlabel("Date")
ax.set_ylabel("price")
plt.tight_layout()
plt.legend(fontsize = 12)
plt.show() # forces render to show the grid to show

# %%
# let start normalizing the data
close.iloc[0,0] #first index of the dataframe
# Out:
# np.float64(24.26104164123535)

# %%
close.AAPL
# Out:
# Date
# 2015-01-02     24.261042
# 2015-01-05     23.577570
# 2015-01-06     23.579796
# 2015-01-07     23.910431
# 2015-01-08     24.829128
#                  ...
# 2024-12-24    257.286682
# 2024-12-26    258.103729
# 2024-12-27    254.685867
# 2024-12-30    251.307877
# 2024-12-31    249.534180
# Name: AAPL, Length: 2516, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])#divides the the rest with first index to normalize the data
# Out:
# Date
# 2015-01-02     1.000000
# 2015-01-05     0.971828
# 2015-01-06     0.971920
# 2015-01-07     0.985548
# 2015-01-08     1.023416
#                 ...
# 2024-12-24    10.604931
# 2024-12-26    10.638609
# 2024-12-27    10.497730
# 2024-12-30    10.358495
# 2024-12-31    10.285386
# Name: AAPL, Length: 2516, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL     24.261042
# KO       30.222618
# SPY     171.568054
# Name: 2015-01-02 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100) # normalize all the data and multiplies by 100
# Out:
#                    AAPL          KO         SPY
# Date
# 2015-01-02   100.000000  100.000000  100.000000
# 2015-01-05    97.182843  100.000000   98.194014
# 2015-01-06    97.192017  100.759390   97.269146
# 2015-01-07    98.554841  102.017064   98.481201
# 2015-01-08   102.341559  103.251047  100.228782
# ...                 ...         ...         ...
# 2024-12-24  1060.493139  204.943467  348.392068
# 2024-12-26  1063.860872  204.062894  348.415298
# 2024-12-27  1049.773011  203.671536  344.747669
# 2024-12-30  1035.849492  202.301760  340.813548
# 2024-12-31  1028.538607  203.051859  339.573656
#
# [2516 rows x 3 columns]

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
ab = normclose.plot(figsize=(12,6), fontsize = 12)
ab.set_title("Normalized Close data for AAPL SPY KO")
ab.set_xlabel("Date")
ab.set_ylabel("Price")
plt.legend(fontsize = 12)
plt.show()

# %%
#want to focus now on the aple stock.
aapl = close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2015-01-02   24.261042
# 2015-01-05   23.577570
# 2015-01-06   23.579796
# 2015-01-07   23.910431
# 2015-01-08   24.829128
# ...                ...
# 2024-12-24  257.286682
# 2024-12-26  258.103729
# 2024-12-27  254.685867
# 2024-12-30  251.307877
# 2024-12-31  249.534180
#
# [2516 rows x 1 columns]

# %%
aapl.shift( periods = 1) #
# Out:
#                   AAPL
# Date
# 2015-01-02         NaN
# 2015-01-05   24.261042
# 2015-01-06   23.577570
# 2015-01-07   23.579796
# 2015-01-08   23.910431
# ...                ...
# 2024-12-24  254.367020
# 2024-12-26  257.286682
# 2024-12-27  258.103729
# 2024-12-30  254.685867
# 2024-12-31  251.307877
#
# [2516 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods = 1) # this creates another column in dataframe of aapl

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2015-01-02   24.261042         NaN
# 2015-01-05   23.577570   24.261042
# 2015-01-06   23.579796   23.577570
# 2015-01-07   23.910431   23.579796
# 2015-01-08   24.829128   23.910431
# ...                ...         ...
# 2024-12-24  257.286682  254.367020
# 2024-12-26  258.103729  257.286682
# 2024-12-27  254.685867  258.103729
# 2024-12-30  251.307877  254.685867
# 2024-12-31  249.534180  251.307877
#
# [2516 rows x 2 columns]

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1) #(Diff) that shows day-to-day price movement

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2015-01-02   24.261042         NaN       NaN
# 2015-01-05   23.577570   24.261042 -0.683472
# 2015-01-06   23.579796   23.577570  0.002226
# 2015-01-07   23.910431   23.579796  0.330635
# 2015-01-08   24.829128   23.910431  0.918697
# ...                ...         ...       ...
# 2024-12-24  257.286682  254.367020  2.919662
# 2024-12-26  258.103729  257.286682  0.817047
# 2024-12-27  254.685867  258.103729 -3.417862
# 2024-12-30  251.307877  254.685867 -3.377991
# 2024-12-31  249.534180  251.307877 -1.773697
#
# [2516 rows x 3 columns]

# %%
aapl["% change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % change
# Date
# 2015-01-02   24.261042         NaN       NaN       NaN
# 2015-01-05   23.577570   24.261042 -0.683472 -2.817157
# 2015-01-06   23.579796   23.577570  0.002226  0.009441
# 2015-01-07   23.910431   23.579796  0.330635  1.402196
# 2015-01-08   24.829128   23.910431  0.918697  3.842245
# ...                ...         ...       ...       ...
# 2024-12-24  257.286682  254.367020  2.919662  1.147815
# 2024-12-26  258.103729  257.286682  0.817047  0.317563
# 2024-12-27  254.685867  258.103729 -3.417862 -1.324220
# 2024-12-30  251.307877  254.685867 -3.377991 -1.326336
# 2024-12-31  249.534180  251.307877 -1.773697 -0.705786
#
# [2516 rows x 4 columns]

# %%
aapl["% change 2"] = aapl.AAPL.pct_change(periods = 1).mul(100) # make the percentage change into readable percentages
aapl
# Out:
#                   AAPL        lag1      Diff  % change  % change 2
# Date
# 2015-01-02   24.261042         NaN       NaN       NaN         NaN
# 2015-01-05   23.577570   24.261042 -0.683472 -2.817157   -2.817157
# 2015-01-06   23.579796   23.577570  0.002226  0.009441    0.009441
# 2015-01-07   23.910431   23.579796  0.330635  1.402196    1.402196
# 2015-01-08   24.829128   23.910431  0.918697  3.842245    3.842245
# ...                ...         ...       ...       ...         ...
# 2024-12-24  257.286682  254.367020  2.919662  1.147815    1.147815
# 2024-12-26  258.103729  257.286682  0.817047  0.317563    0.317563
# 2024-12-27  254.685867  258.103729 -3.417862 -1.324220   -1.324220
# 2024-12-30  251.307877  254.685867 -3.377991 -1.326336   -1.326336
# 2024-12-31  249.534180  251.307877 -1.773697 -0.705786   -0.705786
#
# [2516 rows x 5 columns]

# %%
del aapl["lag1"]
del aapl["Diff"]
del aapl["% change"] # deleting columns

# %%
aapl
# Out:
#                   AAPL  % change 2
# Date
# 2015-01-02   24.261042         NaN
# 2015-01-05   23.577570   -2.817157
# 2015-01-06   23.579796    0.009441
# 2015-01-07   23.910431    1.402196
# 2015-01-08   24.829128    3.842245
# ...                ...         ...
# 2024-12-24  257.286682    1.147815
# 2024-12-26  258.103729    0.317563
# 2024-12-27  254.685867   -1.324220
# 2024-12-30  251.307877   -1.326336
# 2024-12-31  249.534180   -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.rename( columns = {"% change 2" : "change"}, inplace = True)

# %%
aapl
# Out:
#                   AAPL    change
# Date
# 2015-01-02   24.261042       NaN
# 2015-01-05   23.577570 -2.817157
# 2015-01-06   23.579796  0.009441
# 2015-01-07   23.910431  1.402196
# 2015-01-08   24.829128  3.842245
# ...                ...       ...
# 2024-12-24  257.286682  1.147815
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307877 -1.326336
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("M").last() # gives monthly
aapl
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_8696\2082094181.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   aapl.AAPL.resample("M").last() # gives monthly
#                   AAPL    change
# Date
# 2015-01-02   24.261042       NaN
# 2015-01-05   23.577570 -2.817157
# 2015-01-06   23.579796  0.009441
# 2015-01-07   23.910431  1.402196
# 2015-01-08   24.829128  3.842245
# ...                ...       ...
# 2024-12-24  257.286682  1.147815
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307877 -1.326336
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("BM").last()# gives last business day
aapl
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_8696\1414886035.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample("BM").last()# gives last business day
#                   AAPL    change
# Date
# 2015-01-02   24.261042       NaN
# 2015-01-05   23.577570 -2.817157
# 2015-01-06   23.579796  0.009441
# 2015-01-07   23.910431  1.402196
# 2015-01-08   24.829128  3.842245
# ...                ...       ...
# 2024-12-24  257.286682  1.147815
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307877 -1.326336
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("BME").last().pct_change(periods = 1).mul(100) # gives percentage change last business day
aapl
# Out:
#                   AAPL    change
# Date
# 2015-01-02   24.261042       NaN
# 2015-01-05   23.577570 -2.817157
# 2015-01-06   23.579796  0.009441
# 2015-01-07   23.910431  1.402196
# 2015-01-08   24.829128  3.842245
# ...                ...       ...
# 2024-12-24  257.286682  1.147815
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307877 -1.326336
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL      change
# Date
# 2015-01-06  0.000094   -1.003351
# 2015-01-07  0.014022  147.527538
# 2015-01-08  0.038422    1.740162
# 2015-01-09  0.001072   -0.972087
# 2015-01-12 -0.024641  -23.975646
# ...              ...         ...
# 2024-12-24  0.011478    2.744986
# 2024-12-26  0.003176   -0.723333
# 2024-12-27 -0.013242   -5.169946
# 2024-12-30 -0.013263    0.001598
# 2024-12-31 -0.007058   -0.467868
#
# [2514 rows x 2 columns]

# %%
ret.replace([float("inf"), float("-inf")], float("nan"), inplace=True)
ret = ret.dropna()
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()

# %%
ret['AAPL'] = ret['AAPL'].apply(lambda x: np.log(x+1) if x > 0 else x)
ret['change'] = ret['change'].apply(lambda x: np.log(abs(x)+1) if x != 0 else x)
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()

# %%
ax = ret['AAPL'].plot(kind="hist", figsize=(12,8), bins=100, color="blue", alpha=0.5)
ret['change'].plot(kind="hist", bins=100, color="orange", alpha=0.5, ax=ax)
ax.set_ylabel('Frequency')
ax.set_title('Stock Price and Change Histogram')
plt.legend(["AAPL", "change"])
plt.show()

# %%
daily_mean_return = ret.mean()
daily_mean_return
# Out:
# AAPL      0.000943
# change    0.670964
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL      0.000308
# change    0.115331
# dtype: float64

# %%
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL      0.017550
# change    0.339604
# dtype: float64

# %%
ret.std()
# Out:
# AAPL      0.017550
# change    0.339604
# dtype: float64

# %%
annual_mean_ret = daily_mean_return*252
annual_mean_ret
# Out:
# AAPL        0.237515
# change    169.083054
# dtype: float64

# %%
annual_var = var_daily * 252
annual_var
# Out:
# AAPL       0.077615
# change    29.063450
# dtype: float64

# %%
annual_std = np.sqrt(annual_var)
annual_std
# Out:
# AAPL      0.278594
# change    5.391053
# dtype: float64
