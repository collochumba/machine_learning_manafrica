columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2015-01-02 to 2024-12-31
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   2516 non-null   float64
#  1   (Close, KO)     2516 non-null   float64
#  2   (Close, SPY)    2516 non-null   float64
#  3   (High, AAPL)    2516 non-null   float64
#  4   (High, KO)      2516 non-null   float64
#  5   (High, SPY)     2516 non-null   float64
#  6   (Low, AAPL)     2516 non-null   float64
#  7   (Low, KO)       2516 non-null   float64
#  8   (Low, SPY)      2516 non-null   float64
#  9   (Open, AAPL)    2516 non-null   float64
#  10  (Open, KO)      2516 non-null   float64
#  11  (Open, SPY)     2516 non-null   float64
#  12  (Volume, AAPL)  2516 non-null   int64
#  13  (Volume, KO)    2516 non-null   int64
#  14  (Volume, SPY)   2516 non-null   int64
# dtypes: float64(12), int64(3)
# memory usage: 314.5 KB

# %%
stocks.to_csv("stocksticker")# using to_csv function to downloaded the stock data

# %%
stocks = pd.read_csv("stocksticker") # read the downloaded csv  file

# %%
stocks
# Out:
#            Price               Close             Close.1             Close.2  \
# 0         Ticker                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2015-01-02   24.26104736328125  29.992610931396484  171.09376525878906
# 3     2015-01-05  23.577573776245117  29.992610931396484   168.0037841796875
# 4     2015-01-06   23.57979393005371  30.220354080200195  166.42140197753906
# ...          ...                 ...                 ...                 ...
# 2513  2024-12-24  257.28668212890625   61.46786880493164   596.0769653320312
# 2514  2024-12-26   258.1037292480469   61.20376968383789   596.1166381835938
# 2515  2024-12-27  254.68588256835938   61.08638381958008    589.841552734375
# 2516  2024-12-30  251.30787658691406   60.67555618286133   583.1105346679688
# 2517  2024-12-31      249.5341796875  60.900535583496094   580.9891357421875
#
#                     High              High.1              High.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2     24.729270393437197  30.177664159356617  172.30141777797954
# 3     24.110149898969926  30.583354224033673    170.210848427002
# 4      23.83942422525078  30.561987533744485   168.8366808900063
# ...                  ...                 ...                 ...
# 2513   257.2966260773909   61.46786880493164   596.1166566065269
# 2514   259.1799258751944  61.370059635945985   597.2466898769559
# 2515  257.78489719249416  61.575466150030834   592.5875109444909
# 2516  252.60328106925755  60.978788588343185   586.5999783678407
# 2517  252.38406352835983  61.066825531025835   585.5095236812081
#
#                      Low               Low.1               Low.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2     23.821671579713147  29.750620128338024   170.0526942652705
# 3     23.391173064448488  29.949908428838356  167.69563139642682
# 4     23.218085117057225  30.063773777572397  165.62185409757927
# ...                  ...                 ...                 ...
# 2513    254.386956808638    60.6559903272862   590.2975890385056
# 2514   256.7186620602343   61.03748346313229   592.8849456716348
# 2515  252.16483330495137   60.85162265914681   585.6284696635397
# 2516  249.86300878941353   60.33320002457718   579.3336317674779
# 2517  248.54767617168994  60.450580694843076   579.3435211584518
#
#                     Open              Open.1              Open.2     Volume  \
# 0                   AAPL                  KO                 SPY       AAPL
# 1                    NaN                 NaN                 NaN        NaN
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close',   'KO'),
#             ( 'Close',  'SPY'),
#             (  'High', 'AAPL'),
#             (  'High',   'KO'),
#             (  'High',  'SPY'),
#             (   'Low', 'AAPL'),
#             (   'Low',   'KO'),
#             (   'Low',  'SPY'),
#             (  'Open', 'AAPL'),
#             (  'Open',   'KO'),
#             (  'Open',  'SPY'),
#             ('Volume', 'AAPL'),
#             ('Volume',   'KO'),
#             ('Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
#convert multiindex to one tuple
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([ ('Close', 'AAPL'),    ('Close', 'KO'),   ('Close', 'SPY'),
#          ('High', 'AAPL'),     ('High', 'KO'),    ('High', 'SPY'),
#           ('Low', 'AAPL'),      ('Low', 'KO'),     ('Low', 'SPY'),
#          ('Open', 'AAPL'),     ('Open', 'KO'),    ('Open', 'SPY'),
#        ('Volume', 'AAPL'),   ('Volume', 'KO'),  ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2015-01-02      24.261047    29.992611    171.093765     24.729270
# 2015-01-05      23.577574    29.992611    168.003784     24.110150
# 2015-01-06      23.579794    30.220354    166.421402     23.839424
# 2015-01-07      23.910435    30.597576    168.495163     24.010292
# 2015-01-08      24.829132    30.967680    171.485153     24.886828
# ...                   ...          ...           ...           ...
# 2024-12-24     257.286682    61.467869    596.076965    257.296626
# 2024-12-26     258.103729    61.203770    596.116638    259.179926
# 2024-12-27     254.685883    61.086384    589.841553    257.784897
# 2024-12-30     251.307877    60.675556    583.110535    252.603281
# 2024-12-31     249.534180    60.900536    580.989136    252.384064
#
#             (High, KO)  (High, SPY)  (Low, AAPL)  (Low, KO)  (Low, SPY)  \
# Date
# 2015-01-02   30.177664   172.301418    23.821672  29.750620  170.052694
# 2015-01-05   30.583354   170.210848    23.391173  29.949908  167.695631
# 2015-01-06   30.561988   168.836681    23.218085  30.063774  165.621854
# 2015-01-07   30.682984   168.836637    23.677432  30.305764  167.304185
# 2015-01-08   31.010385   171.701704    24.121249  30.675868  169.894407
# ...                ...          ...          ...        ...         ...
# 2024-12-24   61.467869   596.116657   254.386957  60.655990  590.297589
# 2024-12-26   61.370060   597.246690   256.718662  61.037483  592.884946
# 2024-12-27   61.575466   592.587511   252.164833  60.851623  585.628470
# 2024-12-30   60.978789   586.599978   249.863009  60.333200  579.333632
# 2024-12-31   61.066826   585.509524   248.547676  60.450581  579.343521
#
#             (Open, AAPL)  (Open, KO)  (Open, SPY)  (Volume, AAPL)  \
# Date
# 2015-01-02     24.718174   30.078019   171.884989       212818400
# 2015-01-05     24.030263   30.384066   170.044280       257142000
# 2015-01-06     23.641928   30.184768   168.311977       263188400
# 2015-01-07     23.788385   30.462344   167.753921       160423600
# 2015-01-08     24.238861   30.732808   169.911055       237458000
# ...                  ...         ...          ...             ...
# 2024-12-24    254.586262   60.841844   590.882491        23234700
# 2024-12-26    257.276679   61.252677   594.292594        27237100
# 2024-12-27    256.917949   61.086384   592.349545        42355300
# min      20.624056    27.488176   155.438812    20.927686    27.872298
# 25%      35.257087    34.165969   212.799782    35.655401    34.422519
# 50%      64.450439    42.199306   274.021484    65.005723    42.576406
# 75%     150.379688    54.500757   400.511314   152.129390    54.988045
# max     258.103729    70.395622   600.509277   259.179926    70.896990
#
#                             Low                                   Open  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# mean    312.868718    92.935270    43.465527   309.348818    93.863011
# std     115.381567    64.817392    10.713432   114.184983    65.424438
# min     156.492870    20.425441    26.453476   153.333308    20.546436
# 25%     213.451335    34.878658    33.957587   212.051372    35.277321
# 50%     274.770586    63.647710    41.948702   273.009649    64.290837
# 75%     402.759362   148.411463    54.135384   397.835384   150.202262
# max     601.754152   256.718662    69.662835   599.728788   257.276679
#
#                                        Volume
#                 KO          SPY          AAPL            KO           SPY
# count  2516.000000  2516.000000  2.516000e+03  2.516000e+03  2.516000e+03
# mean     43.771539   311.185093  1.170853e+08  1.411074e+07  8.743599e+07
# std      10.798065   114.821368  6.839614e+07  6.139293e+06  4.490947e+07
# min      27.488172   154.996786  2.323470e+07  2.996300e+06  2.027000e+07
# 25%      34.193909   212.863401  7.105610e+07  1.032540e+07  5.893120e+07
# 50%      42.284201   274.044309  1.003646e+08  1.282735e+07  7.659475e+07
# 75%      54.534715   400.440722  1.426216e+08  1.598612e+07  1.022602e+08
# max      70.675230   600.390786  6.488252e+08  6.784570e+07  5.072443e+08

# %%
close = stocks.loc[:,'Close'].copy() # copy the details to close

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2015-01-02   24.261047  29.992611  171.093765
# 2015-01-05   23.577574  29.992611  168.003784
# 2015-01-06   23.579794  30.220354  166.421402
# 2015-01-07   23.910435  30.597576  168.495163
# 2015-01-08   24.829132  30.967680  171.485153
# ...                ...        ...         ...
# 2024-12-24  257.286682  61.467869  596.076965
# 2024-12-26  258.103729  61.203770  596.116638
# 2024-12-27  254.685883  61.086384  589.841553
# 2024-12-30  251.307877  60.675556  583.110535
# 2024-12-31  249.534180  60.900536  580.989136
#
# [2516 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
ax = close.plot(figsize=(12,6), fontsize = 12)
ax.set_title("Closing Prices for AAPL KO SPY")
ax.set_xlabel("Date")
ax.set_ylabel("price")
plt.tight_layout()
plt.legend(fontsize = 12)
plt.show() # forces render to show the grid to show

# %%
# let start normalizing the data
close.iloc[0,0] #first index of the dataframe
# Out:
# np.float64(24.26104736328125)

# %%
close.AAPL
# Out:
# Date
# 2015-01-02     24.261047
# 2015-01-05     23.577574
# 2015-01-06     23.579794
# 2015-01-07     23.910435
# 2015-01-08     24.829132
#                  ...
# 2024-12-24    257.286682
# 2024-12-26    258.103729
# 2024-12-27    254.685883
# 2024-12-30    251.307877
# 2024-12-31    249.534180
# Name: AAPL, Length: 2516, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])#divides the the rest with first index to normalize the data
# Out:
# Date
# 2015-01-02     1.000000
# 2015-01-05     0.971828
# 2015-01-06     0.971920
# 2015-01-07     0.985548
# 2015-01-08     1.023416
#                 ...
# 2024-12-24    10.604929
# 2024-12-26    10.638606
# 2024-12-27    10.497728
# 2024-12-30    10.358492
# 2024-12-31    10.285384
# Name: AAPL, Length: 2516, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL     24.261047
# KO       29.992611
# SPY     171.093765
# Name: 2015-01-02 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100) # normalize all the data and multiplies by 100
# Out:
#                    AAPL          KO         SPY
# Date
# 2015-01-02   100.000000  100.000000  100.000000
# 2015-01-05    97.182836  100.000000   98.193984
# 2015-01-06    97.191987  100.759331   97.269121
# 2015-01-07    98.554833  102.017048   98.481182
# 2015-01-08   102.341551  103.251031  100.228756
# ...                 ...         ...         ...
# 2024-12-24  1060.492889  204.943374  348.391985
# 2024-12-26  1063.860621  204.062827  348.415173
# 2024-12-27  1049.772826  203.671444  344.747543
# 2024-12-30  1035.849248  202.301681  340.813433
# 2024-12-31  1028.538364  203.051797  339.573529
#
# [2516 rows x 3 columns]

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
ab = normclose.plot(figsize=(12,6), fontsize = 12)
ab.set_title("Normalized Close data for AAPL SPY KO")
ab.set_xlabel("Date")
ab.set_ylabel("Price")
plt.legend(fontsize = 12)
plt.show()

# %%
#want to focus now on the aple stock.
aapl = close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2015-01-02   24.261047
# 2015-01-05   23.577574
# 2015-01-06   23.579794
# 2015-01-07   23.910435
# 2015-01-08   24.829132
# ...                ...
# 2024-12-24  257.286682
# 2024-12-26  258.103729
# 2024-12-27  254.685883
# 2024-12-30  251.307877
# 2024-12-31  249.534180
#
# [2516 rows x 1 columns]

# %%
aapl.shift( periods = 1) #
# Out:
#                   AAPL
# Date
# 2015-01-02         NaN
# 2015-01-05   24.261047
# 2015-01-06   23.577574
# 2015-01-07   23.579794
# 2015-01-08   23.910435
# ...                ...
# 2024-12-24  254.367035
# 2024-12-26  257.286682
# 2024-12-27  258.103729
# 2024-12-30  254.685883
# 2024-12-31  251.307877
#
# [2516 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods = 1) # this creates another column in dataframe of aapl

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2015-01-02   24.261047         NaN
# 2015-01-05   23.577574   24.261047
# 2015-01-06   23.579794   23.577574
# 2015-01-07   23.910435   23.579794
# 2015-01-08   24.829132   23.910435
# ...                ...         ...
# 2024-12-24  257.286682  254.367035
# 2024-12-26  258.103729  257.286682
# 2024-12-27  254.685883  258.103729
# 2024-12-30  251.307877  254.685883
# 2024-12-31  249.534180  251.307877
#
# [2516 rows x 2 columns]

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1) #(Diff) that shows day-to-day price movement

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2015-01-02   24.261047         NaN       NaN
# 2015-01-05   23.577574   24.261047 -0.683474
# 2015-01-06   23.579794   23.577574  0.002220
# 2015-01-07   23.910435   23.579794  0.330641
# 2015-01-08   24.829132   23.910435  0.918697
# ...                ...         ...       ...
# 2024-12-24  257.286682  254.367035  2.919647
# 2024-12-26  258.103729  257.286682  0.817047
# 2024-12-27  254.685883  258.103729 -3.417847
# 2024-12-30  251.307877  254.685883 -3.378006
# 2024-12-31  249.534180  251.307877 -1.773697
#
# [2516 rows x 3 columns]

# %%
aapl["% change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % change
# Date
# 2015-01-02   24.261047         NaN       NaN       NaN
# 2015-01-05   23.577574   24.261047 -0.683474 -2.817164
# 2015-01-06   23.579794   23.577574  0.002220  0.009416
# 2015-01-07   23.910435   23.579794  0.330641  1.402221
# 2015-01-08   24.829132   23.910435  0.918697  3.842244
# ...                ...         ...       ...       ...
# 2024-12-24  257.286682  254.367035  2.919647  1.147809
# 2024-12-26  258.103729  257.286682  0.817047  0.317563
# 2024-12-27  254.685883  258.103729 -3.417847 -1.324214
# 2024-12-30  251.307877  254.685883 -3.378006 -1.326342
# 2024-12-31  249.534180  251.307877 -1.773697 -0.705786
#
# [2516 rows x 4 columns]

# %%
aapl["% change 2"] = aapl.AAPL.pct_change(periods = 1).mul(100) # make the percentage change into readable percentages
aapl
# Out:
#                   AAPL        lag1      Diff  % change  % change 2
# Date
# 2015-01-02   24.261047         NaN       NaN       NaN         NaN
# 2015-01-05   23.577574   24.261047 -0.683474 -2.817164   -2.817164
# 2015-01-06   23.579794   23.577574  0.002220  0.009416    0.009416
# 2015-01-07   23.910435   23.579794  0.330641  1.402221    1.402221
# 2015-01-08   24.829132   23.910435  0.918697  3.842244    3.842244
# ...                ...         ...       ...       ...         ...
# 2024-12-24  257.286682  254.367035  2.919647  1.147809    1.147809
# 2024-12-26  258.103729  257.286682  0.817047  0.317563    0.317563
# 2024-12-27  254.685883  258.103729 -3.417847 -1.324214   -1.324214
# 2024-12-30  251.307877  254.685883 -3.378006 -1.326342   -1.326342
# 2024-12-31  249.534180  251.307877 -1.773697 -0.705786   -0.705786
#
# [2516 rows x 5 columns]

# %%
del aapl["lag1"]
del aapl["Diff"]
del aapl["% change"] # deleting columns

# %%
aapl
# Out:
#                   AAPL  % change 2
# Date
# 2015-01-02   24.261047         NaN
# 2015-01-05   23.577574   -2.817164
# 2015-01-06   23.579794    0.009416
# 2015-01-07   23.910435    1.402221
# 2015-01-08   24.829132    3.842244
# ...                ...         ...
# 2024-12-24  257.286682    1.147809
# 2024-12-26  258.103729    0.317563
# 2024-12-27  254.685883   -1.324214
# 2024-12-30  251.307877   -1.326342
# 2024-12-31  249.534180   -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.rename( columns = {"% change 2" : "change"}, inplace = True)

# %%
aapl
# Out:
#                   AAPL    change
# Date
# 2015-01-02   24.261047       NaN
# 2015-01-05   23.577574 -2.817164
# 2015-01-06   23.579794  0.009416
# 2015-01-07   23.910435  1.402221
# 2015-01-08   24.829132  3.842244
# ...                ...       ...
# 2024-12-24  257.286682  1.147809
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685883 -1.324214
# 2024-12-30  251.307877 -1.326342
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("M").last() # gives monthly
aapl
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_13184\2082094181.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   aapl.AAPL.resample("M").last() # gives monthly
#                   AAPL    change
# Date
# 2015-01-02   24.261047       NaN
# 2015-01-05   23.577574 -2.817164
# 2015-01-06   23.579794  0.009416
# 2015-01-07   23.910435  1.402221
# 2015-01-08   24.829132  3.842244
# ...                ...       ...
# 2024-12-24  257.286682  1.147809
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685883 -1.324214
# 2024-12-30  251.307877 -1.326342
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("BM").last()# gives last business day
aapl
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_13184\1414886035.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample("BM").last()# gives last business day
#                   AAPL    change
# Date
# 2015-01-02   24.261047       NaN
# 2015-01-05   23.577574 -2.817164
# 2015-01-06   23.579794  0.009416
# 2015-01-07   23.910435  1.402221
# 2015-01-08   24.829132  3.842244
# ...                ...       ...
# 2024-12-24  257.286682  1.147809
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685883 -1.324214
# 2024-12-30  251.307877 -1.326342
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("BME").last().pct_change(periods = 1).mul(100) # gives percentage change last business day
aapl
# Out:
#                   AAPL    change
# Date
# 2015-01-02   24.261047       NaN
# 2015-01-05   23.577574 -2.817164
# 2015-01-06   23.579794  0.009416
# 2015-01-07   23.910435  1.402221
# 2015-01-08   24.829132  3.842244
# ...                ...       ...
# 2024-12-24  257.286682  1.147809
# 2024-12-26  258.103729  0.317563
# 2024-12-27  254.685883 -1.324214
# 2024-12-30  251.307877 -1.326342
# 2024-12-31  249.534180 -0.705786
#
# [2516 rows x 2 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL      change
# Date
# 2015-01-06  0.000094   -1.003343
# 2015-01-07  0.014022  147.912954
# 2015-01-08  0.038422    1.740114
# 2015-01-09  0.001072   -0.972089
# 2015-01-12 -0.024641  -23.977437
# ...              ...         ...
# 2024-12-24  0.011478    2.744966
# 2024-12-26  0.003176   -0.723331
# 2024-12-27 -0.013242   -5.169927
# 2024-12-30 -0.013263    0.001607
# 2024-12-31 -0.007058   -0.467870
#
# [2514 rows x 2 columns]

# %%
ret.replace([float("inf"), float("-inf")], float("nan"), inplace=True)
ret = ret.dropna()
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()

# %%
ret['AAPL'] = ret['AAPL'].apply(lambda x: np.log(x+1) if x > 0 else x)
ret['change'] = ret['change'].apply(lambda x: np.log(abs(x)+1) if x != 0 else x)
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_13184\1755525925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ret['AAPL'] = ret['AAPL'].apply(lambda x: np.log(x+1) if x > 0 else x)
# C:\Users\chumb\AppData\Local\Temp\ipykernel_13184\1755525925.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ret['change'] = ret['change'].apply(lambda x: np.log(abs(x)+1) if x != 0 else x)

# %%
ax = ret['AAPL'].plot(kind="hist", figsize=(12,8), bins=100, color="blue", alpha=0.5)
ret['change'].plot(kind="hist", bins=100, color="orange", alpha=0.5, ax=ax)
ax.set_ylabel('Frequency')
ax.set_title('Stock Price and Change Histogram')
plt.legend(["AAPL", "change"])
plt.show()

# %%
daily_mean_return = ret.mean()
daily_mean_return
# Out:
# AAPL      0.001024
# change    1.081112
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL      0.000314
# change    0.660230
# dtype: float64

# %%
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL      0.017727
# change    0.812546
# dtype: float64

# %%
ret.std()
# Out:
# AAPL      0.017727
# change    0.812546
# dtype: float64

# %%
annual_mean_ret = daily_mean_return*252
annual_mean_ret
# Out:
# AAPL        0.257981
# change    272.440160
# dtype: float64

# %%
annual_var = var_daily * 252
annual_var
# Out:
# AAPL        0.079192
# change    166.378048
# dtype: float64

# %%
annual_std = np.sqrt(annual_var)
annual_std
# Out:
# AAPL       0.281411
# change    12.898761
# dtype: float64

# %%
ticker = ["SPY","AAPL","kO","IBM","DIS","MSFT"]
stocks=yf.download(ticker, start = "2015-01-01" , end = "2025-01-01")
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_13184\4157262885.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks=yf.download(ticker, start = "2015-01-01" , end = "2025-01-01")
# [*********************100%***********************]  6 of 6 completed

# %%
close = stocks.loc[ :,"Close"].copy() #choose the close
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2015-01-05 -0.028172 -0.014613 -0.015735  0.000000 -0.009196 -0.018060
# 2015-01-06  0.000094 -0.005304 -0.021566  0.007593 -0.014677 -0.009419
# 2015-01-07  0.014022  0.010230 -0.006535  0.012482  0.012705  0.012461
# 2015-01-08  0.038422  0.010341  0.021735  0.012096  0.029418  0.017745
# 2015-01-09  0.001072  0.004905  0.004355 -0.011032 -0.008405 -0.008014

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    2515.0  0.001088  0.017929 -0.128647 -0.007326  0.001000  0.010142
# DIS     2515.0  0.000255  0.017537 -0.131632 -0.007131  0.000098  0.008085
# IBM     2515.0  0.000424  0.015004 -0.128507 -0.006350  0.000768  0.007403
# KO      2515.0  0.000345  0.011204 -0.096725 -0.004593  0.000551  0.005747
# MSFT    2515.0  0.001081  0.017096 -0.147391 -0.006736  0.000958  0.009768
# SPY     2515.0  0.000548  0.011099 -0.109424 -0.003705  0.000596  0.005928
#
#              max
# Ticker
# AAPL    0.119808
# DIS     0.144123
# IBM     0.113010
# KO      0.064795
# MSFT    0.142169
# SPY     0.090603

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001088  0.017929
# DIS     0.000255  0.017537
# IBM     0.000424  0.015004
# KO      0.000345  0.011204
# MSFT    0.001081  0.017096
# SPY     0.000548  0.011099

# %%
summary ["mean"]= summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.274140  0.284618
# DIS     0.064184  0.278397
# IBM     0.106780  0.238178
# KO      0.086883  0.177859
# MSFT    0.272487  0.271390
# SPY     0.138110  0.176192

# %%
summary.plot.scatter(x="std", y="mean",figsize=(12,8), s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i,"std"]+ 0.002, summary.loc[i, "mean"]+0.02), size=15)
plt.show()

# %% [markdown]
# Correlation and covariance

# %%
ret
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2015-01-05 -0.028172 -0.014613 -0.015735  0.000000 -0.009196 -0.018060
# 2015-01-06  0.000094 -0.005304 -0.021566  0.007593 -0.014677 -0.009419
# 2015-01-07  0.014022  0.010230 -0.006535  0.012482  0.012705  0.012461
# 2015-01-08  0.038422  0.010341  0.021735  0.012096  0.029418  0.017745
# 2015-01-09  0.001072  0.004905  0.004355 -0.011032 -0.008405 -0.008014
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-24  0.011478  0.010413  0.011175  0.007374  0.009374  0.011115
# 2024-12-26  0.003176 -0.000089  0.002139 -0.004297 -0.002777  0.000067
# 2024-12-27 -0.013242 -0.008885 -0.009382 -0.001918 -0.017302 -0.010527
# 2024-12-30 -0.013263 -0.006723 -0.011356 -0.006725 -0.013240 -0.011412
# 2024-12-31 -0.007058  0.004964 -0.001907  0.003708 -0.007838 -0.003638
#
# [2515 rows x 6 columns]

# %%
ret.cov() # coverance of the matrix
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    0.000321  0.000130  0.000107  0.000074  0.000209  0.000149
# DIS     0.000130  0.000308  0.000106  0.000078  0.000132  0.000122
# IBM     0.000107  0.000106  0.000225  0.000079  0.000113  0.000105
# KO      0.000074  0.000078  0.000079  0.000126  0.000077  0.000073
# MSFT    0.000209  0.000132  0.000113  0.000077  0.000292  0.000151
# SPY     0.000149  0.000122  0.000105  0.000073  0.000151  0.000123

# %%
ret.corr()#correlation of the matrix
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    1.000000  0.413371  0.397704  0.367808  0.682852  0.747368
# DIS     0.413371  1.000000  0.401442  0.395461  0.441456  0.628928
# IBM     0.397704  0.401442  1.000000  0.469249  0.440134  0.628158
# KO      0.367808  0.395461  0.469249  1.000000  0.402613  0.589649
# MSFT    0.682852  0.441456  0.440134  0.402613  1.000000  0.795566
# SPY     0.747368  0.628928  0.628158  0.589649  0.795566  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))#size of the figure
sns.set(font_scale =1.4)#this is the scale of the font how big or small it is
sns.heatmap(ret.corr(),cmap="Greens",annot=True,annot_kws={"size":15},vmax=0.6)# thsi is the heatmap with setting like color for cmapaand annotation settings
plt.show()# so that the map is show

# %% [markdown]
# #Simple returns and logs

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95], columns=['Prices'])

# %%
df
# Out:
#       Prices
# 2016     100
# 2017      50
# 2018      95

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       Prices
# 2017    -0.5
# 2018     0.9

# %%
simplereturns.mean()
# Out:
# Prices    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
#the simple returns is misleading and therefore we should use the logs since it drops the first data for 2016
#the above cell was suppose to end in 95 as in the df dataframe

# %%
logreturns =np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#         Prices
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Prices   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2) # it should give 95
# Out:
# Prices    95.0
# dtype: float64

# %%
SPY = yf.download("SPY", start="1993-01-01", end="2025-01-01")
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_13184\1326799806.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   SPY = yf.download("SPY", start="1993-01-01", end="2025-01-01")
# [*********************100%***********************]  1 of 1 completed

# %%
print(SPY.head())
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker            SPY        SPY        SPY        SPY      SPY
# Date
# 1993-01-29  24.313040  24.330332  24.209286  24.330332  1003200
# 1993-02-01  24.485952  24.485952  24.330321  24.330321   480500
# 1993-02-02  24.537840  24.555132  24.416793  24.468671   201300
# 1993-02-03  24.797218  24.814511  24.555126  24.572418   529400
# 1993-02-04  24.900988  24.952865  24.607018  24.883695   531500

# %%
spy = SPY['Close']['SPY'].to_frame()

# %%
spy
# Out:
#                    SPY
# Date
# 1993-01-29   24.313040
# 1993-02-01   24.485952
# 1993-02-02   24.537840
# 1993-02-03   24.797218
# 1993-02-04   24.900988
# ...                ...
# 2024-12-24  596.076965
# 2024-12-26  596.116699
# 2024-12-27  589.841614
# 2024-12-30  583.110596
# 2024-12-31  580.989136
#
# [8038 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy_roll=spy.rolling(window=10)
spy_roll=spy_roll.mean()
spy_roll
# Out:
#                    SPY
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-12-24  592.063483
# 2024-12-26  591.658801
# 2024-12-27  590.935858
# 2024-12-30  589.551660
# 2024-12-31  587.700415
#
# [8038 rows x 1 columns]

# %%
spy.rolling(window=10, min_periods=5).max().head(15)
# Out:
#                   SPY
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04  24.900988
# 1993-02-05  24.900988
# 1993-02-08  24.900988
# 1993-02-09  24.900988
# 1993-02-10  24.900988
# 1993-02-11  24.900988
# 1993-02-12  24.900988
# 1993-02-16  24.900988
# 1993-02-17  24.900988
# 1993-02-18  24.900988
# 1993-02-19  24.883678

# %%
spy
# Out:
#                    SPY
# Date
# 1993-01-29   24.313040
# 1993-02-01   24.485952
# 1993-02-02   24.537840
# 1993-02-03   24.797218
# 1993-02-04   24.900988
# ...                ...
# 2024-12-24  596.076965
# 2024-12-26  596.116699
# 2024-12-27  589.841614
# 2024-12-30  583.110596
# 2024-12-31  580.989136
#
# [8038 rows x 1 columns]

# %%
spy
# Out:
# Ticker             SPY
# Date
# 1993-01-29   24.313040
# 1993-02-01   24.485952
# 1993-02-02   24.537840
# 1993-02-03   24.797218
# 1993-02-04   24.900988
# ...                ...
# 2024-12-24  596.076965
# 2024-12-26  596.116699
# 2024-12-27  589.841614
# 2024-12-30  583.110596
# 2024-12-31  580.989136
#
# [8038 rows x 1 columns]

# %%
spy_close = SPY['Close', 'SPY'].to_frame()

# %%
spy_close
# Out:
#                  Close
#                    SPY
# Date
# 1993-01-29   24.313040
# 1993-02-01   24.485952
# 1993-02-02   24.537840
# 1993-02-03   24.797218
# 1993-02-04   24.900988
# ...                ...
# 2024-12-24  596.076965
# 2024-12-26  596.116699
# 2024-12-27  589.841614
# 2024-12-30  583.110596
# 2024-12-31  580.989136
#
# [8038 rows x 1 columns]

# %%
spy["SMA50"]=spy_close.rolling(window=50, min_periods= 50).mean()

# %%
spy
# Out:
#                    SPY       SMA50
# Date
# 1993-01-29   24.313040         NaN
# 1993-02-01   24.485952         NaN
# 1993-02-02   24.537840         NaN
# 1993-02-03   24.797218         NaN
# 1993-02-04   24.900988         NaN
# ...                ...         ...
# 2024-12-24  596.076965  584.993628
# 2024-12-26  596.116699  585.459642
# 2024-12-27  589.841614  585.750360
# 2024-12-30  583.110596  585.905471
# 2024-12-31  580.989136  585.973890
#
# [8038 rows x 2 columns]

# %%
spy["SMA200"]=spy_close.rolling(window=200, min_periods= 200).mean() #Moving average for 200

# %%
spy
# Out:
#                    SPY       SMA50      SMA200
# Date
# 1993-01-29   24.313040         NaN         NaN
# 1993-02-01   24.485952         NaN         NaN
# 1993-02-02   24.537840         NaN         NaN
# 1993-02-03   24.797218         NaN         NaN
# 1993-02-04   24.900988         NaN         NaN
# ...                ...         ...         ...
# 2024-12-24  596.076965  584.993628  543.879300
# 2024-12-26  596.116699  585.459642  544.330868
# 2024-12-27  589.841614  585.750360  544.755025
# 2024-12-30  583.110596  585.905471  545.150519
# 2024-12-31  580.989136  585.973890  545.552709
#
# [8038 rows x 3 columns]

# %%
spy.plot(figsize=(15,8), fontsize=12)
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %%
spy["EMA100"]=spy.SPY.ewm(span=100, min_periods=100).mean()

# %%
spy
# Out:
#                    SPY       SMA50      SMA200      EMA100
# Date
# 1993-01-29   24.313040         NaN         NaN         NaN
# 1993-02-01   24.485952         NaN         NaN         NaN
# 1993-02-02   24.537840         NaN         NaN         NaN
# 1993-02-03   24.797218         NaN         NaN         NaN
# 1993-02-04   24.900988         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2024-12-24  596.076965  584.993628  543.879300  570.384408
# 2024-12-26  596.116699  585.459642  544.330868  570.893958
# 2024-12-27  589.841614  585.750360  544.755025  571.269159
# 2024-12-30  583.110596  585.905471  545.150519  571.503643
# 2024-12-31  580.989136  585.973890  545.552709  571.691475
#
# [8038 rows x 4 columns]

# %%
spy.plot(figsize=(15,8), fontsize=12)
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %%
spy['Day']=spy.index.day_name()
spy["Quarter"]= spy.index.quarter

# %%
spy
# Out:
#                    SPY       SMA50      SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   24.313040         NaN         NaN         NaN     Friday        1
# 1993-02-01   24.485952         NaN         NaN         NaN     Monday        1
# 1993-02-02   24.537840         NaN         NaN         NaN    Tuesday        1
# 1993-02-03   24.797218         NaN         NaN         NaN  Wednesday        1
# 1993-02-04   24.900988         NaN         NaN         NaN   Thursday        1
# ...                ...         ...         ...         ...        ...      ...
# 2024-12-24  596.076965  584.993628  543.879300  570.384408    Tuesday        4
# 2024-12-26  596.116699  585.459642  544.330868  570.893958   Thursday        4
# 2024-12-27  589.841614  585.750360  544.755025  571.269159     Friday        4
# 2024-12-30  583.110596  585.905471  545.150519  571.503643     Monday        4
# 2024-12-31  580.989136  585.973890  545.552709  571.691475    Tuesday        4
#
# [8038 rows x 6 columns]

# %%
sp
