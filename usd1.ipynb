# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2015-01-01" , end = "2025-01-01")# downloading the data for apple AAPL is the trade mark for apple.
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14236\472372654.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Apple = yf.download("AAPL", start = "2015-01-01" , end = "2025-01-01")# downloading the data for apple AAPL is the trade mark for apple.
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2015-01-02   24.261044   24.729267   23.821668   24.718171  212818400
# 2015-01-05   23.577572   24.110148   23.391171   24.030261  257142000
# 2015-01-06   23.579794   23.839424   23.218085   23.641928  263188400
# 2015-01-07   23.910431   24.010288   23.677428   23.788382  160423600
# 2015-01-08   24.829128   24.886824   24.121246   24.238858  237458000
# ...                ...         ...         ...         ...        ...
# 2024-12-24  257.286652  257.296596  254.386927  254.586231   23234700
# 2024-12-26  258.103729  259.179926  256.718662  257.276679   27237100
# 2024-12-27  254.685867  257.784882  252.164818  256.917934   42355300
# 2024-12-30  251.307861  252.603266  249.862994  251.337754   35557500
# 2024-12-31  249.534180  252.384064  248.547676  251.547039   39480700
#
# [2516 rows x 5 columns]

# %%
ticker = ["SPY","AAPL","kO"]

# %%
stocks = yf.download(ticker, start = "2015-01-01" , end = "2025-01-01") # this is downloading the multiple stocks
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14236\1368731124.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks = yf.download(ticker, start = "2015-01-01" , end = "2025-01-01") # this is downloading the multiple stocks
# [*********************100%***********************]  3 of 3 completed

# %%
stocks
# Out:
# Price            Close                               High             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2015-01-02   24.261044  30.222618  171.568054   24.729267  30.409090
# 2015-01-05   23.577572  30.222618  168.469589   24.110148  30.817892
# 2015-01-06   23.579794  30.452114  166.882751   23.839424  30.796368
# 2015-01-07   23.910431  30.832235  168.962326   24.010288  30.918298
# 2015-01-08   24.829128  31.205177  171.960571   24.886824  31.248210
# ...                ...        ...         ...         ...        ...
# 2024-12-24  257.286652  61.939281  597.729492  257.296596  61.939281
# 2024-12-26  258.103729  61.673145  597.769348  259.179926  61.840711
# 2024-12-27  254.685867  61.554871  591.476868  257.784882  62.047704
# 2024-12-30  251.307861  61.140888  584.727173  252.603266  61.446446
# 2024-12-31  249.534180  61.367588  582.599915  252.384064  61.535153
#
# Price                          Low                               Open  \
# Ticker             SPY        AAPL         KO         SPY        AAPL
# Date
# 2015-01-02  172.779054   23.821668  29.978772  170.524097   24.718171
# 2015-01-05  170.682773   23.391171  30.179588  168.160582   24.030261
# 2015-01-06  169.304726   23.218085  30.294333  166.080987   23.641928
# 2015-01-07  169.304747   23.677428  30.538185  167.768046   23.788382
# 2015-01-08  172.177722   24.121246  30.911127  170.365415   24.238858
# ...                ...         ...        ...         ...         ...
# 2024-12-24  597.769293  254.386927  61.121176  591.934094  254.586231
# 2024-12-26  598.902533  256.718662  61.505584  594.528696  257.276679
# 2024-12-27  594.230439  252.164818  61.318309  587.252104  256.917934
# 2024-12-30  588.226291  249.862994  60.795906  580.939799  251.337754
# 2024-12-31  587.132835  248.547676  60.914182  580.949738  251.547039
#
# Price                                 Volume
# Ticker             KO         SPY       AAPL        KO        SPY
# Date
# 2015-01-02  30.308681  172.361472  212818400   9921100  121465900
# 2015-01-05  30.617075  170.515742  257142000  26292600  169632600
# 2015-01-06  30.416255  168.778568  263188400  16897500  209151400
# 2015-01-07  30.695966  168.219029  160423600  13412300  125346700
# 2015-01-08  30.968504  170.382109  237458000  21743600  147217800
# ...               ...         ...        ...       ...        ...
# 2024-12-24  61.308456  592.520617   23234700   5019100   33160100
# 2024-12-26  61.722428  595.940247   27237100   7943800   41219100
# 2024-12-27  61.554871  593.991813   42355300   8542800   64969300
# 2024-12-30  61.446446  584.399176   35557500   8972200   56578800
# 2024-12-31  61.131030  586.407129   39480700   9256700   57052700
#
# [2516 rows x 15 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2015-01-02 to 2024-12-31
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   2516 non-null   float64
#  1   (Close, KO)     2516 non-null   float64
#  2   (Close, SPY)    2516 non-null   float64
#  3   (High, AAPL)    2516 non-null   float64
#  4   (High, KO)      2516 non-null   float64
#  5   (High, SPY)     2516 non-null   float64
#  6   (Low, AAPL)     2516 non-null   float64
#  7   (Low, KO)       2516 non-null   float64
#  8   (Low, SPY)      2516 non-null   float64
#  9   (Open, AAPL)    2516 non-null   float64
#  10  (Open, KO)      2516 non-null   float64
#  11  (Open, SPY)     2516 non-null   float64
#  12  (Volume, AAPL)  2516 non-null   int64
#  13  (Volume, KO)    2516 non-null   int64
#  14  (Volume, SPY)   2516 non-null   int64
# dtypes: float64(12), int64(3)
# memory usage: 314.5 KB

# %%
stocks.to_csv("stocksticker")# using to_csv function to downloaded the stock data

# %%
stocks = pd.read_csv("stocksticker") # read the downloaded csv  file

# %%
stocks
# Out:
#            Price               Close             Close.1             Close.2  \
# 0         Ticker                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2015-01-02  24.261043548583984  30.222618103027344  171.56805419921875
# 3     2015-01-05  23.577571868896484  30.222618103027344  168.46958923339844
# 4     2015-01-06   23.57979393005371   30.45211410522461  166.88275146484375
# ...          ...                 ...                 ...                 ...
# 2513  2024-12-24   257.2866516113281   61.93928146362305      597.7294921875
# 2514  2024-12-26   258.1037292480469   61.67314529418945   597.7693481445312
# 2515  2024-12-27   254.6858673095703   61.55487060546875   591.4768676757812
# 2516  2024-12-30    251.307861328125   61.14088821411133   584.7271728515625
# 2517  2024-12-31      249.5341796875   61.36758804321289   582.5999145507812
#
#                     High              High.1              High.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2     24.729266505118662   30.40909046617586  172.77905445134888
# 3     24.110147948537623  30.817891684615038  170.68277275764044
# 4      23.83942422525078   30.79636754718904  169.30472595657378
# ...                  ...                 ...                 ...
# 2513   257.2965955586333   61.93928146362305   597.7692934996265
# 2514   259.1799258751944   61.84071053453828   598.9025328618192
# 2515  257.78488174803636    62.0477038308768   594.2304389583717
# 2516  252.60326573181473  61.446446164838434   588.2262908200153
# 2517  252.38406352835983  61.535153285422325   587.1328351597793
#
#                      Low               Low.1               Low.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      23.82166783410134  29.978771522214174  170.52409725332382
# 3     23.391171172179064  30.179588123749788   168.1605820698364
# 4     23.218085117057225  30.294332987584554   166.0809870970999
# ...                  ...                 ...                 ...
# 2513  254.38692663500538    61.1211764842439   591.9340935091342
# 2514   256.7186620602343   61.50558381385949   594.5286958920398
# 2515  252.16481819720389   61.31830900286448   587.2521039804407
# 2516  249.86299361835324   60.79590646330579   580.9397987194927
# 2517  248.54767617168994  60.914182404324364    580.949737539049
#
#                     Open              Open.1              Open.2     Volume  \
# 0                   AAPL                  KO                 SPY       AAPL
# 1                    NaN                 NaN                 NaN        NaN
#             ( 'Close',   'KO'),
#             ( 'Close',  'SPY'),
#             (  'High', 'AAPL'),
#             (  'High',   'KO'),
#             (  'High',  'SPY'),
#             (   'Low', 'AAPL'),
#             (   'Low',   'KO'),
#             (   'Low',  'SPY'),
#             (  'Open', 'AAPL'),
#             (  'Open',   'KO'),
#             (  'Open',  'SPY'),
#             ('Volume', 'AAPL'),
#             ('Volume',   'KO'),
#             ('Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
#convert multiindex to one tuple
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([ ('Close', 'AAPL'),    ('Close', 'KO'),   ('Close', 'SPY'),
#          ('High', 'AAPL'),     ('High', 'KO'),    ('High', 'SPY'),
#           ('Low', 'AAPL'),      ('Low', 'KO'),     ('Low', 'SPY'),
#          ('Open', 'AAPL'),     ('Open', 'KO'),    ('Open', 'SPY'),
#        ('Volume', 'AAPL'),   ('Volume', 'KO'),  ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2015-01-02      24.261044    30.222618    171.568054     24.729267
# 2015-01-05      23.577572    30.222618    168.469589     24.110148
# 2015-01-06      23.579794    30.452114    166.882751     23.839424
# 2015-01-07      23.910431    30.832235    168.962326     24.010288
# 2015-01-08      24.829128    31.205177    171.960571     24.886824
# ...                   ...          ...           ...           ...
# 2024-12-24     257.286652    61.939281    597.729492    257.296596
# 2024-12-26     258.103729    61.673145    597.769348    259.179926
# 2024-12-27     254.685867    61.554871    591.476868    257.784882
# 2024-12-30     251.307861    61.140888    584.727173    252.603266
# 2024-12-31     249.534180    61.367588    582.599915    252.384064
#
#             (High, KO)  (High, SPY)  (Low, AAPL)  (Low, KO)  (Low, SPY)  \
# Date
# 2015-01-02   30.409090   172.779054    23.821668  29.978772  170.524097
# 2015-01-05   30.817892   170.682773    23.391171  30.179588  168.160582
# 2015-01-06   30.796368   169.304726    23.218085  30.294333  166.080987
# 2015-01-07   30.918298   169.304747    23.677428  30.538185  167.768046
# 2015-01-08   31.248210   172.177722    24.121246  30.911127  170.365415
# ...                ...          ...          ...        ...         ...
# 2024-12-24   61.939281   597.769293   254.386927  61.121176  591.934094
# 2024-12-26   61.840711   598.902533   256.718662  61.505584  594.528696
# 2024-12-27   62.047704   594.230439   252.164818  61.318309  587.252104
# 2024-12-30   61.446446   588.226291   249.862994  60.795906  580.939799
# 2024-12-31   61.535153   587.132835   248.547676  60.914182  580.949738
#
#             (Open, AAPL)  (Open, KO)  (Open, SPY)  (Volume, AAPL)  \
# Date
# 2015-01-02     24.718171   30.308681   172.361472       212818400
# 2015-01-05     24.030261   30.617075   170.515742       257142000
# 2015-01-06     23.641928   30.416255   168.778568       263188400
# 2015-01-07     23.788382   30.695966   168.219029       160423600
# 2015-01-08     24.238858   30.968504   170.382109       237458000
# ...                  ...         ...          ...             ...
# 2024-12-24    254.586231   61.308456   592.520617        23234700
# 2024-12-26    257.276679   61.722428   595.940247        27237100
# 2024-12-27    256.917934   61.554871   593.991813        42355300
# 2024-12-30    251.337754   61.446446   584.399176        35557500
# 25%      35.257084    34.427996   213.389748    35.655394    34.686504
# 50%      64.450447    42.522943   274.781265    65.005702    42.902921
# 75%     150.379654    54.918732   401.621758   152.129370    55.409758
# max     258.103729    70.935493   602.174133   259.179926    71.440715
#
#                             Low                                   Open  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# mean    313.736124    92.935271    43.798871   310.206465    93.863012
# std     115.701453    64.817392    10.795596   114.501552    65.424438
# min     156.926731    20.425428    26.656349   153.758470    20.546430
# 25%     214.043092    34.878663    34.218007   212.639270    35.277322
# 50%     275.532392    63.647697    42.270410   273.766549    64.290837
# 75%     403.875947   148.411474    54.550558   398.938326   150.202228
# max     603.422460   256.718662    70.197086   601.391480   257.276679
#
#                                        Volume
#                 KO          SPY          AAPL            KO           SPY
# count  2516.000000  2516.000000  2.516000e+03  2.516000e+03  2.516000e+03
# mean     44.107230   312.047831  1.170853e+08  1.411074e+07  8.743599e+07
# std      10.880877   115.139701  6.839614e+07  6.139293e+06  4.490947e+07
# min      27.698980   155.426500  2.323470e+07  2.996300e+06  2.027000e+07
# 25%      34.456161   213.453564  7.105610e+07  1.032540e+07  5.893120e+07
# 50%      42.608491   274.804075  1.003646e+08  1.282735e+07  7.659475e+07
# 75%      54.952957   401.550987  1.426216e+08  1.598612e+07  1.022602e+08
# max      71.217255   602.055220  6.488252e+08  6.784570e+07  5.072443e+08

# %%
close = stocks.loc[:,'Close'].copy() # copy the details to close

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2015-01-02   24.261044  30.222618  171.568054
# 2015-01-05   23.577572  30.222618  168.469589
# 2015-01-06   23.579794  30.452114  166.882751
# 2015-01-07   23.910431  30.832235  168.962326
# 2015-01-08   24.829128  31.205177  171.960571
# ...                ...        ...         ...
# 2024-12-24  257.286652  61.939281  597.729492
# 2024-12-26  258.103729  61.673145  597.769348
# 2024-12-27  254.685867  61.554871  591.476868
# 2024-12-30  251.307861  61.140888  584.727173
# 2024-12-31  249.534180  61.367588  582.599915
#
# [2516 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
ax = close.plot(figsize=(12,6), fontsize = 12)
ax.set_title("Closing Prices for AAPL KO SPY")
ax.set_xlabel("Date")
ax.set_ylabel("price")
plt.tight_layout()
plt.legend(fontsize = 12)
plt.show() # forces render to show the grid to show

# %%
# let start normalizing the data
close.iloc[0,0] #first index of the dataframe
# Out:
# np.float64(24.261043548583984)

# %%
close.AAPL
# Out:
# Date
# 2015-01-02     24.261044
# 2015-01-05     23.577572
# 2015-01-06     23.579794
# 2015-01-07     23.910431
# 2015-01-08     24.829128
#                  ...
# 2024-12-24    257.286652
# 2024-12-26    258.103729
# 2024-12-27    254.685867
# 2024-12-30    251.307861
# 2024-12-31    249.534180
# Name: AAPL, Length: 2516, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])#divides the the rest with first index to normalize the data
# Out:
# Date
# 2015-01-02     1.000000
# 2015-01-05     0.971828
# 2015-01-06     0.971920
# 2015-01-07     0.985548
# 2015-01-08     1.023416
#                 ...
# 2024-12-24    10.604929
# 2024-12-26    10.638608
# 2024-12-27    10.497729
# 2024-12-30    10.358493
# 2024-12-31    10.285385
# Name: AAPL, Length: 2516, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL     24.261044
# KO       30.222618
# SPY     171.568054
# Name: 2015-01-02 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100) # normalize all the data and multiplies by 100
# Out:
#                    AAPL          KO         SPY
# Date
# 2015-01-02   100.000000  100.000000  100.000000
# 2015-01-05    97.182843  100.000000   98.194032
# 2015-01-06    97.192002  100.759352   97.269129
# 2015-01-07    98.554833  102.017089   98.481228
# 2015-01-08   102.341551  103.251072  100.228782
# ...                 ...         ...         ...
# 2024-12-24  1060.492930  204.943467  348.392068
# 2024-12-26  1063.860789  204.062881  348.415298
# 2024-12-27  1049.772928  203.671536  344.747669
# 2024-12-30  1035.849348  202.301760  340.813548
# 2024-12-31  1028.538526  203.051859  339.573656
#
# [2516 rows x 3 columns]

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
ab = normclose.plot(figsize=(12,6), fontsize = 12)
ab.set_title("Normalized Close data for AAPL SPY KO")
ab.set_xlabel("Date")
ab.set_ylabel("Price")
plt.legend(fontsize = 12)
plt.show()

# %%
#want to focus now on the aple stock.
aapl = close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2015-01-02   24.261044
# 2015-01-05   23.577572
# 2015-01-06   23.579794
# 2015-01-07   23.910431
# 2015-01-08   24.829128
# ...                ...
# 2024-12-24  257.286652
# 2024-12-26  258.103729
# 2024-12-27  254.685867
# 2024-12-30  251.307861
# 2024-12-31  249.534180
#
# [2516 rows x 1 columns]

# %%
aapl.shift( periods = 1) #
# Out:
#                   AAPL
# Date
# 2015-01-02         NaN
# 2015-01-05   24.261044
# 2015-01-06   23.577572
# 2015-01-07   23.579794
# 2015-01-08   23.910431
# ...                ...
# 2024-12-24  254.367020
# 2024-12-26  257.286652
# 2024-12-27  258.103729
# 2024-12-30  254.685867
# 2024-12-31  251.307861
#
# [2516 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods = 1) # this creates another column in dataframe of aapl

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2015-01-02   24.261044         NaN
# 2015-01-05   23.577572   24.261044
# 2015-01-06   23.579794   23.577572
# 2015-01-07   23.910431   23.579794
# 2015-01-08   24.829128   23.910431
# ...                ...         ...
# 2024-12-24  257.286652  254.367020
# 2024-12-26  258.103729  257.286652
# 2024-12-27  254.685867  258.103729
# 2024-12-30  251.307861  254.685867
# 2024-12-31  249.534180  251.307861
#
# [2516 rows x 2 columns]

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1) #(Diff) that shows day-to-day price movement

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2015-01-02   24.261044         NaN       NaN
# 2015-01-05   23.577572   24.261044 -0.683472
# 2015-01-06   23.579794   23.577572  0.002222
# 2015-01-07   23.910431   23.579794  0.330637
# 2015-01-08   24.829128   23.910431  0.918697
# ...                ...         ...       ...
# 2024-12-24  257.286652  254.367020  2.919632
# 2024-12-26  258.103729  257.286652  0.817078
# 2024-12-27  254.685867  258.103729 -3.417862
# 2024-12-30  251.307861  254.685867 -3.378006
# 2024-12-31  249.534180  251.307861 -1.773682
#
# [2516 rows x 3 columns]

# %%
aapl["% change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % change
# Date
# 2015-01-02   24.261044         NaN       NaN       NaN
# 2015-01-05   23.577572   24.261044 -0.683472 -2.817157
# 2015-01-06   23.579794   23.577572  0.002222  0.009424
# 2015-01-07   23.910431   23.579794  0.330637  1.402205
# 2015-01-08   24.829128   23.910431  0.918697  3.842245
# ...                ...         ...       ...       ...
# 2024-12-24  257.286652  254.367020  2.919632  1.147803
# 2024-12-26  258.103729  257.286652  0.817078  0.317575
# 2024-12-27  254.685867  258.103729 -3.417862 -1.324220
# 2024-12-30  251.307861  254.685867 -3.378006 -1.326342
# 2024-12-31  249.534180  251.307861 -1.773682 -0.705780
#
# [2516 rows x 4 columns]

# %%
aapl["% change 2"] = aapl.AAPL.pct_change(periods = 1).mul(100) # make the percentage change into readable percentages
aapl
# Out:
#                   AAPL        lag1      Diff  % change  % change 2
# Date
# 2015-01-02   24.261044         NaN       NaN       NaN         NaN
# 2015-01-05   23.577572   24.261044 -0.683472 -2.817157   -2.817157
# 2015-01-06   23.579794   23.577572  0.002222  0.009424    0.009424
# 2015-01-07   23.910431   23.579794  0.330637  1.402205    1.402205
# 2015-01-08   24.829128   23.910431  0.918697  3.842245    3.842245
# ...                ...         ...       ...       ...         ...
# 2024-12-24  257.286652  254.367020  2.919632  1.147803    1.147803
# 2024-12-26  258.103729  257.286652  0.817078  0.317575    0.317575
# 2024-12-27  254.685867  258.103729 -3.417862 -1.324220   -1.324220
# 2024-12-30  251.307861  254.685867 -3.378006 -1.326342   -1.326342
# 2024-12-31  249.534180  251.307861 -1.773682 -0.705780   -0.705780
#
# [2516 rows x 5 columns]

# %%
del aapl["lag1"]
del aapl["Diff"]
del aapl["% change"] # deleting columns

# %%
aapl
# Out:
#                   AAPL  % change 2
# Date
# 2015-01-02   24.261044         NaN
# 2015-01-05   23.577572   -2.817157
# 2015-01-06   23.579794    0.009424
# 2015-01-07   23.910431    1.402205
# 2015-01-08   24.829128    3.842245
# ...                ...         ...
# 2024-12-24  257.286652    1.147803
# 2024-12-26  258.103729    0.317575
# 2024-12-27  254.685867   -1.324220
# 2024-12-30  251.307861   -1.326342
# 2024-12-31  249.534180   -0.705780
#
# [2516 rows x 2 columns]

# %%
aapl.rename( columns = {"% change 2" : "change"}, inplace = True)

# %%
aapl
# Out:
#                   AAPL    change
# Date
# 2015-01-02   24.261044       NaN
# 2015-01-05   23.577572 -2.817157
# 2015-01-06   23.579794  0.009424
# 2015-01-07   23.910431  1.402205
# 2015-01-08   24.829128  3.842245
# ...                ...       ...
# 2024-12-24  257.286652  1.147803
# 2024-12-26  258.103729  0.317575
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307861 -1.326342
# 2024-12-31  249.534180 -0.705780
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("M").last() # gives monthly
aapl
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14236\2082094181.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   aapl.AAPL.resample("M").last() # gives monthly
#                   AAPL    change
# Date
# 2015-01-02   24.261044       NaN
# 2015-01-05   23.577572 -2.817157
# 2015-01-06   23.579794  0.009424
# 2015-01-07   23.910431  1.402205
# 2015-01-08   24.829128  3.842245
# ...                ...       ...
# 2024-12-24  257.286652  1.147803
# 2024-12-26  258.103729  0.317575
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307861 -1.326342
# 2024-12-31  249.534180 -0.705780
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("BM").last()# gives last business day
aapl
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14236\1414886035.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample("BM").last()# gives last business day
#                   AAPL    change
# Date
# 2015-01-02   24.261044       NaN
# 2015-01-05   23.577572 -2.817157
# 2015-01-06   23.579794  0.009424
# 2015-01-07   23.910431  1.402205
# 2015-01-08   24.829128  3.842245
# ...                ...       ...
# 2024-12-24  257.286652  1.147803
# 2024-12-26  258.103729  0.317575
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307861 -1.326342
# 2024-12-31  249.534180 -0.705780
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("BME").last().pct_change(periods = 1).mul(100) # gives percentage change last business day
aapl
# Out:
#                   AAPL    change
# Date
# 2015-01-02   24.261044       NaN
# 2015-01-05   23.577572 -2.817157
# 2015-01-06   23.579794  0.009424
# 2015-01-07   23.910431  1.402205
# 2015-01-08   24.829128  3.842245
# ...                ...       ...
# 2024-12-24  257.286652  1.147803
# 2024-12-26  258.103729  0.317575
# 2024-12-27  254.685867 -1.324220
# 2024-12-30  251.307861 -1.326342
# 2024-12-31  249.534180 -0.705780
#
# [2516 rows x 2 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL      change
# Date
# 2015-01-06  0.000094   -1.003345
# 2015-01-07  0.014022  147.783403
# 2015-01-08  0.038422    1.740146
# 2015-01-09  0.001073   -0.972085
# 2015-01-12 -0.024641  -23.973927
# ...              ...         ...
# 2024-12-24  0.011478    2.744873
# 2024-12-26  0.003176   -0.723319
# 2024-12-27 -0.013242   -5.169790
# 2024-12-30 -0.013263    0.001602
# 2024-12-31 -0.007058   -0.467875
#
# [2514 rows x 2 columns]

# %%
ret.replace([float("inf"), float("-inf")], float("nan"), inplace=True)
ret = ret.dropna()
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()

# %%
ret['AAPL'] = ret['AAPL'].apply(lambda x: np.log(x+1) if x > 0 else x)
ret['change'] = ret['change'].apply(lambda x: np.log(abs(x)+1) if x != 0 else x)
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14236\1755525925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ret['AAPL'] = ret['AAPL'].apply(lambda x: np.log(x+1) if x > 0 else x)
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14236\1755525925.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ret['change'] = ret['change'].apply(lambda x: np.log(abs(x)+1) if x != 0 else x)

# %%
ax = ret['AAPL'].plot(kind="hist", figsize=(12,8), bins=100, color="blue", alpha=0.5)
ret['change'].plot(kind="hist", bins=100, color="orange", alpha=0.5, ax=ax)
ax.set_ylabel('Frequency')
ax.set_title('Stock Price and Change Histogram')
plt.legend(["AAPL", "change"])
plt.show()

# %%
daily_mean_return = ret.mean()
daily_mean_return
# Out:
# AAPL      0.001024
# change    1.081116
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL      0.000314
# change    0.660254
# dtype: float64

# %%
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL      0.017727
# change    0.812560
# dtype: float64

# %%
ret.std()
# Out:
# AAPL      0.017727
# change    0.812560
# dtype: float64

# %%
annual_mean_ret = daily_mean_return*252
annual_mean_ret
# Out:
# AAPL        0.257981
# change    272.441113
# dtype: float64

# %%
annual_var = var_daily * 252
annual_var
# Out:
# AAPL        0.079192
# change    166.383947
# dtype: float64

# %%
annual_std = np.sqrt(annual_var)
annual_std
# Out:
# AAPL       0.281411
# change    12.898990
# dtype: float64

# %%
ticker = ["SPY","AAPL","kO","IBM","DIS","MSFT"]
stocks=yf.download(ticker, start = "2015-01-01" , end = "2025-01-01")
# Out:
# C:\Users\chumb\AppData\Local\Temp\ipykernel_14236\4157262885.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks=yf.download(ticker, start = "2015-01-01" , end = "2025-01-01")
# [*********************100%***********************]  6 of 6 completed

# %%
close = stocks.loc[ :,"Close"].copy() #choose the close
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2015-01-05 -0.028172 -0.014613 -0.015735  0.000000 -0.009196 -0.018060
# 2015-01-06  0.000094 -0.005304 -0.021566  0.007594 -0.014677 -0.009419
# 2015-01-07  0.014022  0.010230 -0.006535  0.012483  0.012706  0.012461
# 2015-01-08  0.038422  0.010341  0.021735  0.012096  0.029418  0.017745
# 2015-01-09  0.001073  0.004905  0.004355 -0.011032 -0.008405 -0.008013

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    2515.0  0.001088  0.017929 -0.128647 -0.007326  0.001000  0.010142
# DIS     2515.0  0.000255  0.017537 -0.131632 -0.007131  0.000098  0.008085
# IBM     2515.0  0.000424  0.015004 -0.128507 -0.006349  0.000768  0.007403
# KO      2515.0  0.000345  0.011204 -0.096725 -0.004593  0.000551  0.005747
# MSFT    2515.0  0.001081  0.017096 -0.147390 -0.006736  0.000958  0.009768
# SPY     2515.0  0.000548  0.011099 -0.109424 -0.003705  0.000596  0.005928
#
#              max
# Ticker
# AAPL    0.119808
# DIS     0.144123
# IBM     0.113010
# KO      0.064796
# MSFT    0.142169
# SPY     0.090603

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001088  0.017929
# DIS     0.000255  0.017537
# IBM     0.000424  0.015004
# KO      0.000345  0.011204
# MSFT    0.001081  0.017096
# SPY     0.000548  0.011099

# %%
summary ["mean"]= summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#              mean          std
# Ticker
# AAPL    69.083235  1138.577163
# DIS     16.174414  1113.692256
# IBM     26.908555   952.800906
# KO      21.894632   711.501837
# MSFT    68.666746  1085.662889
# SPY     34.803841   704.833740

# %%
summary.plot.scatter(x="std", y="mean",figsize=(12,8), s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i,"std"]+ 0.002, summary.loc[i, "mean"]+0.02), size=15)
plt.show()
